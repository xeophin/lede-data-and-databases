# %%
import requests
from bs4 import BeautifulSoup

# %%
my_url = "https://www.tribecafilm.com/filmguide?letter=b"
raw_html = requests.get(my_url)
soup_doc = BeautifulSoup(raw_html.content, "html.parser")

# %%
print(soup_doc.prettify())
#soup_doc.title
# Out:
# <!DOCTYPE html>
# <html class="no-js" xmlns:fb="http://ogp.me/ns/fb#" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <title>
#    Film Guide | Tribeca
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="ZrgBmxCT8kS6RfVMm6fO-YCaQ1mqWPDhraWTyXr_Db4" name="google-site-verification"/>
#   <meta content="Film Guide | Tribeca" property="og:title"/>
#   <meta content="https://www.tribecafilm.com/assets/logo-meta-52027c2180d9deca680a506865b4c82a7dd61dc69873a28242efc5d59ae56a51.png" property="og:image"/>
#   <meta content="Tribecafilm.com: Home of the  Tribeca Film Festival" property="og:description"/>
#   <meta content="http://www.tribecafilm.com/filmguide?letter=b" property="og:url"/>
#   <meta content="Tribeca" property="og:site_name"/>
#   <meta content="232295416876278" property="fb:app_id"/>
#   <link href="/assets/application-c93a0e4e9b9c234c7ab01de367da7218f91c4f6c9a85755c00e869fc40c6584f.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/films/films-list-0b3963959c5f103d2a022197732ba6e689551da25e0e6738746703314a42a407.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/print-836ef6346990f3e4675e43cc213397e1b2da1387712babbe6b139dd9ec8e87fa.css" media="print" rel="stylesheet"/>
#   <link href="/feed.xml" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="hifwwMwZv/9Hp1Cxz+japrT8K8sOYZuMMsD1U4ogL1VHLPCwIujNdj15Hk4DwgJQnlWy+Lv50h+QZRE+KcSrew==" name="csrf-token"/>
#  </head>
#  <body base-section="festival" class="tffSection films-filmguide films-index" nav-state="closed">
#   <section class="WishlistTray do empty">
#    <header class="WT__header">
#     <div class="title">
#      MY WISH LIST
#     </div>
#    </header>
#    <section class="WT__nostatus">
#     <div class="WT__col-2 link--101">
#      <i>
#      </i>
#      <p>
#       We're making it easier than ever for you to stock up on Tribeca Film
#         Festival tickets. Our revamped Wish List will save you time and effort
#         in singling out the Festival titles you cannot wait to see.
#      </p>
#      <a class="WLI__link" href="/festival/tickets">
#       LEARN MORE
#      </a>
#     </div>
#     <div class="WT__col-2 link--sign_in">
#      <i>
#      </i>
#      <p>
#       To take advantage of the Wish List, you must have a My Tribeca account.
#           Creating a My Tribeca account gives you access to more features and services,
#           like Wish Lists.
#      </p>
#      <a class="WLI__link" href="/users/sign_in">
#       SIGN IN
#      </a>
#     </div>
#    </section>
#    <button class="WT__close closeX px18">
#    </button>
#   </section>
#   <section id="mainHeader">
#    <header class="sectionBorderColor" id="uniHeader">
#     <button aria-label="Menu" class="hamburger" id="globalNavBurger">
#      <span>
#      </span>
#     </button>
#     <section id="masthead">
#      <!-- <a href="" class="sectionLogo ir">Tribeca</a> NOTE-AM -->
#      <a class="sectionLogo ir" href="/festival">
#      </a>
#     </section>
#     <nav class="rightIcons">
#      <button class="globalWishlist do">
#       <span class="wlcount">
#       </span>
#      </button>
#      <button aria-label="Account" class="globalAcct sectionText--hover do">
#       P
#      </button>
#      <button aria-label="Search" class="globalSearch sectionText--hover do">
#       S
#      </button>
#      <button aria-label="More Settings" clπass="gearIcon mo" id="globalGear">
#      </button>
#     </nav>
#    </header>
#    <section class="headerTray" id="acctTray">
#     <div class="signedOut cf">
#      <div class="container">
#       <p class="title">
#        SIGN UP
#       </p>
#       <p class="text">
#        Creating an account with Tribecafilm.com gives you access to more features and services, like our weekly newsletter and other special features just for the film community.
#       </p>
#       <a class="linkButton" href="/users/sign_up">
#        SIGN UP
#       </a>
#      </div>
#      <div class="container">
#       <p class="title">
#        SIGN IN
#       </p>
#       <form accept-charset="UTF-8" action="/users/sign_in" autocomplete="off" class="form2015" id="signIn" method="post">
#        <input name="utf8" type="hidden" value="✓"/>
#        <input name="authenticity_token" type="hidden" value="s7WGzehTDFFxO2y5HJgPz5FxAnJkK/sijcCvHlhyf/9yvoa9BqJ+2AvlIkbQstc5u9ibQdGzsrEvZUtz+5b70Q=="/>
#        <div class="field">
#         <input class="formSwap sectionBorderColor--focus" id="user_email" name="user[email]" placeholder="Enter your email" type="text"/>
#        </div>
#        <div class="field">
#         <input class="formSwap sectionBorderColor--focus" id="user_password" name="user[password]" placeholder="Password" type="password"/>
#        </div>
#        <input class="linkButton" data-disable-with="SIGN IN" name="commit" type="submit" value="SIGN IN"/>
#        <a class="linkButton fb" href="/users/auth/facebook">
#         SIGN IN WITH THE FACEBOOK
#        </a>
#       </form>
#      </div>
#     </div>
#     <button class="closeX mo">
#     </button>
#    </section>
#    <section class="headerTray" id="searchTray">
#     <form accept-charset="UTF-8" action="/browse" autocomplete="off" id="search_form" method="get">
#      <input name="utf8" type="hidden" value="✓"/>
#      <input id="q" name="q" placeholder="Type here to search" type="text"/>
#     </form>
#    </section>
#    <section class="mo" id="gearTray">
#     <div class="tray">
#      <a class="" href="/festival/wishlist">
#       WISH LIST
#       <span class="icon--star-black">
#       </span>
#      </a>
#      <a class="globalAcct" href="#">
#       ACCOUNT
#       <span class="icon--account">
#       </span>
#      </a>
#      <a class="globalSearch" href="#">
#       SEARCH
#       <span class="icon--search">
#       </span>
#      </a>
#     </div>
#    </section>
#    <nav id="superNav" sub-nav="tribeca">
#     <section id="primaryNav">
#      <div class="tray">
#       <ul class="mainlinks">
#        <li>
#         <a href="/">
#          Tribeca
#         </a>
#        </li>
#        <li>
#         <a href="#" sub-nav-opens="tff">
#          Film Festival
#         </a>
#        </li>
#        <li>
#         <a href="/TVfestival">
#          TV Festival
#         </a>
#        </li>
#        <li>
#         <a href="/games">
#          Tribeca Games
#         </a>
#        </li>
#        <li>
#         <a href="/studios">
#          Tribeca Studios
#         </a>
#        </li>
#       </ul>
#       <hr/>
#       <ul class="sublinks">
#        <li>
#         <a class="" href="/sponsorship" rel="">
#          Partnership
#         </a>
#        </li>
#        <li>
#         <a class="" href="/festival/industry" rel="">
#          Industry
#         </a>
#        </li>
#        <li>
#         <a class="" href="/contact" rel="">
#          Contact
#         </a>
#        </li>
#        <li>
#         <a class="" href="/festival/jobs" rel="">
#          Jobs &amp; Crew
#         </a>
#        </li>
#        <li>
#         <a href="/tvfest/submissions">
#          2018 TV Festival Submissions
#         </a>
#        </li>
#       </ul>
#       <!-- <hr/> -->
#       <footer>
#        <nav class="social">
#         <p class="title">
#          FOLLOW US
#         </p>
#         <a class="socialIcon socFB ir" href="https://www.facebook.com/Tribeca" target="_blank">
#          Facebook
#         </a>
#         <a class="socialIcon socTwitter ir" href="http://twitter.com/tribeca" target="_blank">
#          Twitter
#         </a>
#         <a class="socialIcon socInsta ir" href="http://instagram.com/tribeca" target="_blank">
#          Instagram
#         </a>
#         <a class="socialIcon socTumblr ir" href="http://tribeca.tumblr.com" target="_blank">
#          Tumblr
#         </a>
#         <a class="socialIcon socYT ir" href="http://www.youtube.com/tribecafilm" target="_blank">
#          Youtube
#         </a>
#         <!--<a class="socialIcon socRSS ir" href="http://tribecafilm.com/feed.xml" target="_blank">RSS</a>-->
#        </nav>
#       </footer>
#      </div>
#     </section>
#     <section id="subNav">
#      <!--
#     <div id="" sub-nav-tray="tribeca" class="tray" >
#       <ul class="mainlinks">
#         <li><a href="/" class="">Home</a></li>
#         <li><a href="/categories/news">News</a></li>
#         <li><a href="/categories/culture">Culture</a></li>
#         <li><a href="/categories/film">Film</a></li>
#         <li><a href="/categories/nyc">NYC</a></li>
#       </ul>
#
#       <hr/>
#       <ul class="mainlinks">
#         <li><a href="/videos">Videos</a></li>
#         <li><a href="/photos">Photos</a></li>
#         <li><a href="/tags/interviews">Interviews</a></li>
#       </ul>
#     </div>
#     -->
#      <div class="tray" id="" sub-nav-tray="tff">
#       <ul class="mainlinks">
#        <li>
#         <a href="/festival">
#          Festival Home
#         </a>
#        </li>
#        <!--<li><a href="/festival/submissions">2018 Festival Submissions</a></li> -->
#        <li>
#         <a href="/filmguide">
#          Festival Guide
#         </a>
#        </li>
#        <li>
#         <a href="/festival/schedule">
#          2018 Schedule
#         </a>
#        </li>
#        <li>
#         <a href="/discover">
#          Discover
#         </a>
#        </li>
#        <li>
#         <a href="/festival/tickets">
#          Tickets &amp; Passes
#         </a>
#        </li>
#        <li>
#         <a href="/filmguide?s_name=TV§ion=56e2f788d66728b9e0000001">
#          Tribeca TV
#         </a>
#        </li>
#        <li>
#         <a href="/festival/tribeca-talks">
#          Tribeca Talks
#         </a>
#        </li>
#        <li>
#         <a href="/filmguide/tribeca-talks-time-s-up-event-2018">
#          TIME'S UP EVENT
#         </a>
#        </li>
#        <li>
#         <a href="/festival/hub">
#          Festival Hub
#         </a>
#        </li>
#        <li>
#         <a href="/audienceaward">
#          Audience Awards
#         </a>
#        </li>
#        <li>
#         <a href="/festival/tribecanow">
#          Tribeca N.O.W.
#         </a>
#        </li>
#        <li>
#         <a href="/immersive">
#          Tribeca Immersive
#         </a>
#        </li>
#        <li>
#         <a href="/festival/espn">
#          Tribeca/ESPN
#         </a>
#        </li>
#        <li>
#         <a href="/festival/tribecaxaward">
#          Tribeca X Award
#         </a>
#        </li>
#        <!-- <li><a href="/earthday">Earth Day</a></li> -->
#        <!-- <li><a href="/festival/jurors">2017 Festival Jurors</a></li> -->
#        <!-- <li><a href="/festival/programmers">Festival Programmers</a></li> -->
#        <li>
#         <a href="/festival/family/tka">
#          Tribeca Kids Access
#         </a>
#        </li>
#        <li>
#         <a href="/categories/festival">
#          News
#         </a>
#        </li>
#        <!-- <li><a href="/festival/audienceawards">Audience AWard</a></li> %> -->
#        <li>
#         <a href="/festival/art2018">
#          Artists Awards
#         </a>
#        </li>
#        <!-- <li><a href="/festival/jurors">Jurors</a></li> %> -->
#        <li>
#         <a href="/festival/travel">
#          Travel
#         </a>
#        </li>
#        <li>
#         <a href="/festival/eat-drink">
#          Eat &amp; Drink
#         </a>
#        </li>
#        <li>
#         <a href="/press-center/festival">
#          Press
#         </a>
#        </li>
#        <li>
#         <a href="https://tribecafilmfestival.merchdirect.com" target="_blank">
#          Shop
#         </a>
#        </li>
#       </ul>
#       <hr/>
#       <ul class="mainlinks">
#        <li>
#         <a href="http://shortstrailers.gallery.video" target="_blank">
#          Shorts Trailers
#         </a>
#        </li>
#        <li>
#         <a href="http://tribecaimmersive.gallery.video" target="_blank">
#          Virtual Arcade Trailers
#         </a>
#        </li>
#       </ul>
#       <!-- <hr/> -->
#       <!-- <ul class="mainlinks do"> -->
#       <!--   <li><a href="/festival/tune&#45;in">Tribeca Tune In</a></li> -->
#       <!--   <li><a href="/festival/imagination">Imagination</a></li> -->
#       <!--   <li><a href="/festival/bomb">The Bomb</a></li> -->
#       <!--   <li><a href="/festival/daringwomen">Daring Women</a></li> -->
#       <!--   <li><a href="/festival/tribecanow">Tribeca N.O.W.</a></li> -->
#       <!--   <li><a href="/festival/creatorsmarket">Digital Creators Market</a></li> -->
#       <!-- </ul> -->
#      </div>
#      <div class="tray" id="" sub-nav-tray="tf">
#       <ul class="mainlinks">
#        <li>
#         <a href="/tribecafilm">
#          New Releases
#         </a>
#        </li>
#        <li>
#         <a href="/tribecafilm/filmguide">
#          Catalog
#         </a>
#        </li>
#        <li>
#         <a href="/tribecafilm/about-tf">
#          About
#         </a>
#        </li>
#        <li>
#         <a href="/press-center/tribeca-film">
#          TRIBECA FILM PRESS
#         </a>
#        </li>
#       </ul>
#       <hr/>
#      </div>
#     </section>
#    </nav>
#    <div class="clickOverlay">
#    </div>
#   </section>
#   <div class="get-app cw">
#    <div class="banner">
#     <span class="icon_2">
#     </span>
#     <p>
#      DOWNLOAD THE TRIBECA APP
#     </p>
#     <span class="icon_1">
#     </span>
#    </div>
#   </div>
#   <div id="wrapper">
#    <section class="survivalStripe do" id="survivalNavStripe">
#     <div class="cw cf">
#      <!-- <a  href="/festival/submissions" class="submissions">
#   <span class="title">Film Submissions</span>
# </a> -->
#      <a class="filmguide" href="/filmguide">
#       <span class="title">
#        Festival Guide
#       </span>
#      </a>
#      <!-- <a href="/festival/schedule" class="schedule"> -->
#      <!--   <span class="title">Schedule</span> -->
#      <!-- </a> -->
#      <a class="discover" href="/discover">
#       <span class="title">
#        Discover
#       </span>
#      </a>
#      <a class="innovation" href="/festival/hub">
#       <span class="title">
#        Festival Hub
#       </span>
#      </a>
#      <a class="buyTickets" href="/festival/tickets">
#       <span class="title">
#        Tickets &amp; Passes
#       </span>
#      </a>
#      <a class="travel" href="/festival/travel" target="_blank">
#       <span class="title">
#        Travel
#       </span>
#      </a>
#      <a class="shop" href="http://tribecafilmfestival.merchdirect.com/" target="_blank">
#       <span class="title">
#        Shop
#       </span>
#      </a>
#      <a class="industry" href="/festival/industry">
#       <span class="title">
#        Industry
#       </span>
#      </a>
#      <a class="pressCenter" href="/press-center">
#       <span class="title">
#        Press Center
#       </span>
#      </a>
#      <a class="eat-drink" href="/festival/eat-drink">
#       <span class="title">
#        Eat &amp; Drink
#       </span>
#      </a>
#      <a class="faq" href="/festival/faq">
#       <span class="title">
#        Faq
#       </span>
#      </a>
#     </div>
#     <div class="pullTab">
#      <i>
#      </i>
#     </div>
#    </section>
#    <section class="do" id="greyCrumb">
#     <div class="cw">
#      <nav class="trail">
#       <a href="/festival">
#        FESTIVAL
#       </a>
#       | FILM GUIDE
#       <a class="archiveLink" href="/filmguide/archive">
#        FILM GUIDE ARCHIVE
#       </a>
#      </nav>
#     </div>
#    </section>
#    <div class="container-fluid">
#     <div class="row">
#      <div class="col-xs-12 col-sm-3 col-lg-2 filters-col">
#       <div class="filters">
#        <h3 class="header">
#         EXPLORE THE PROGRAM
#        </h3>
#        <div id="filters">
#         <h4 class="item js-item">
#          <i class="fa fa-plus">
#          </i>
#          Alphabetical
#         </h4>
#         <div class="letters">
#          <a class="letter" href="/filmguide?letter=%23">
#           #
#          </a>
#          <a class="letter" href="/filmguide?letter=0">
#           0
#          </a>
#          <a class="letter" href="/filmguide?letter=1">
#           1
#          </a>
#          <a class="letter" href="/filmguide?letter=7">
#           7
#          </a>
#          <a class="letter" href="/filmguide?letter=9">
#           9
#          </a>
#          <a class="letter" href="/filmguide?letter=A">
#           A
#          </a>
#          <div class="clearfix">
#          </div>
#          <a class="letter" href="/filmguide?letter=B">
#           B
#          </a>
#          <a class="letter" href="/filmguide?letter=C">
#           C
#          </a>
#          <a class="letter" href="/filmguide?letter=D">
#           D
#          </a>
#          <a class="letter" href="/filmguide?letter=E">
#           E
#          </a>
#          <a class="letter" href="/filmguide?letter=F">
#           F
#          </a>
#          <a class="letter" href="/filmguide?letter=G">
#           G
#          </a>
#          <div class="clearfix">
#          </div>
#          <a class="letter" href="/filmguide?letter=H">
#           H
#          </a>
#          <a class="letter" href="/filmguide?letter=I">
#           I
#          </a>
#          <a class="letter" href="/filmguide?letter=J">
#           J
#          </a>
#          <a class="letter" href="/filmguide?letter=K">
#           K
#          </a>
#          <a class="letter" href="/filmguide?letter=L">
#           L
#          </a>
#          <a class="letter" href="/filmguide?letter=M">
#           M
#          </a>
#          <div class="clearfix">
#          </div>
#          <a class="letter" href="/filmguide?letter=N">
#           N
#          </a>
#          <a class="letter" href="/filmguide?letter=O">
#           O
#          </a>
#          <a class="letter" href="/filmguide?letter=P">
#           P
#          </a>
#          <a class="letter" href="/filmguide?letter=Q">
#           Q
#          </a>
#          <a class="letter" href="/filmguide?letter=R">
#           R
#          </a>
#          <a class="letter" href="/filmguide?letter=S">
#           S
#          </a>
#          <div class="clearfix">
#          </div>
#          <a class="letter" href="/filmguide?letter=T">
#           T
#          </a>
#          <a class="letter" href="/filmguide?letter=U">
#           U
#          </a>
#          <a class="letter" href="/filmguide?letter=V">
#           V
#          </a>
#          <a class="letter" href="/filmguide?letter=W">
#           W
#          </a>
#          <a class="letter" href="/filmguide?letter=Y">
#           Y
#          </a>
#          <a class="letter" href="/filmguide?letter=Z">
#           Z
#          </a>
#          <div class="clearfix">
#          </div>
#         </div>
#         <h4 class="item js-item">
#          <i class="fa fa-plus">
#          </i>
#          By Section
#         </h4>
#         <ul>
#          <li>
#           <a href="/filmguide?s_name=Awards+Screenings&amp;section=512d46b61c7d76af1f000019">
#            Awards Screenings
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Cinema360&amp;section=5aaaa0dbdaeedf00195e3bae">
#            Cinema360
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Community+Programs&amp;section=5ad8e3d7193c8d5a2fb321c2">
#            Community Programs
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Documentary+Competition&amp;section=56e2f3b8e1d3de39f8000001">
#            Documentary Competition
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Gala&amp;section=512d46b61c7d76af1f00002b">
#            Gala
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=International+Narrative+Competition&amp;section=56e2ef8da32a616049000001">
#            International Narrative Competition
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Midnight&amp;section=513cc012c07f5dbcf700000a">
#            Midnight
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Retrospective+Special+Screenings&amp;section=58c9c4f401e92ee4f9000001">
#            Retrospective Special Screenings
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Shorts&amp;section=58c6d07c5cae2b6caa000001">
#            Shorts
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Shorts+Program&amp;section=51409b3fc07f5d1744000001">
#            Shorts Program
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Special+Screenings&amp;section=512d46b61c7d76af1f00001d">
#            Special Screenings
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Spotlight+Documentary&amp;section=58c6c5dfd667288530000001">
#            Spotlight Documentary
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Spotlight+Narrative&amp;section=58c6c564f5405fc217000001">
#            Spotlight Narrative
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Storyscapes&amp;section=514255aac07f5d47ac000021">
#            Storyscapes
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=TFI+Events&amp;section=570d337d7de2ff72d4000001">
#            TFI Events
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Tribeca+Games&amp;section=58dc62ffaaf016b8a1000002">
#            Tribeca Games
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Tribeca+N.O.W.+Showcase&amp;section=58d54c5601e92eae5a000001">
#            Tribeca N.O.W. Showcase
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Tribeca+TV&amp;section=56e2f788d66728b9e0000001">
#            Tribeca TV
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Tribeca+Talks&amp;section=512d46b61c7d76af1f000016">
#            Tribeca Talks
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Tribeca+Talks%3A+Directors+Series&amp;section=56f461321f099e4b7a000002">
#            Tribeca Talks: Directors Series
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Tribeca+Talks%3A+Master+Class&amp;section=58d09bd9da05d67401000001">
#            Tribeca Talks: Master Class
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Tribeca+Talks%3A+Storytellers&amp;section=56f4611168ffd4d1a3000001">
#            Tribeca Talks: Storytellers
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=US+Narrative+Competition&amp;section=56e2ee6685286201fc000003">
#            US Narrative Competition
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Viewpoints&amp;section=512d46b61c7d76af1f000029">
#            Viewpoints
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?s_name=Virtual+Arcade&amp;section=56e736727de2ffab61000001">
#            Virtual Arcade
#           </a>
#          </li>
#         </ul>
#         <h4 class="item js-item">
#          <i class="fa fa-plus">
#          </i>
#          By Genre
#         </h4>
#         <ul>
#          <li>
#           <a href="/filmguide?genre=">
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Action">
#            Action
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=African+American+Director%28s%29">
#            African American Director(s)
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Animation">
#            Animation
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Asian+American+Director%28s%29">
#            Asian American Director(s)
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Comedy">
#            Comedy
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Documentary">
#            Documentary
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Drama">
#            Drama
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Environmental">
#            Environmental
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Experimental">
#            Experimental
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Female+Director%28s%29">
#            Female Director(s)
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Female+Screenwriter%28s%29">
#            Female Screenwriter(s)
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=First+Time+Filmmaker">
#            First Time Filmmaker
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Horror">
#            Horror
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=LGBT">
#            LGBT
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Latino+Director%28s%29">
#            Latino Director(s)
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Music">
#            Music
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=NY+Director%28s%29">
#            NY Director(s)
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=New+York">
#            New York
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Science+Fiction">
#            Science Fiction
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Sports">
#            Sports
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Technology">
#            Technology
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Thriller">
#            Thriller
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Tribeca+Film+Festival+Alumni">
#            Tribeca Film Festival Alumni
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?genre=Tribeca+Film+Institute+Alumni">
#            Tribeca Film Institute Alumni
#           </a>
#          </li>
#         </ul>
#         <h4 class="item js-item">
#          <i class="fa fa-plus">
#          </i>
#          By Venue
#         </h4>
#         <ul>
#          <li>
#           <a href="/filmguide?t_name=BMCC+Tribeca+PAC&amp;theater=512cd85b1c7d76e046000026">
#            BMCC Tribeca PAC
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?t_name=Beacon+Theater&amp;theater=54da6cc1d667288792000002">
#            Beacon Theater
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?t_name=Cin%C3%A9polis+Chelsea&amp;theater=512cdd171c7d76e046000338">
#            Cinépolis Chelsea
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?t_name=PUBLIC+Hotel&amp;theater=5ad00810ad9b4113be87a856">
#            PUBLIC Hotel
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?t_name=Regal+Cinemas+Battery+Park&amp;theater=54e60885e1d3de50e6000002">
#            Regal Cinemas Battery Park
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?t_name=SVA+Theatre&amp;theater=512cd8461c7d76e046000018">
#            SVA Theatre
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?t_name=Tribeca+Festival+Hub&amp;theater=54e61629d66728d20a000002">
#            Tribeca Festival Hub
#           </a>
#          </li>
#         </ul>
#         <h4 class="item js-item">
#          <i class="fa fa-plus">
#          </i>
#          By Country
#         </h4>
#         <ul>
#          <li>
#           <a href="/filmguide?country=Argentina">
#            Argentina
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Australia">
#            Australia
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Austria">
#            Austria
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Belgium">
#            Belgium
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Brazil">
#            Brazil
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Canada">
#            Canada
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Chile">
#            Chile
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=China">
#            China
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Cyprus">
#            Cyprus
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Denmark">
#            Denmark
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=France">
#            France
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Germany">
#            Germany
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Greece">
#            Greece
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Greenland">
#            Greenland
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=India">
#            India
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Iraq">
#            Iraq
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Ireland">
#            Ireland
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Israel">
#            Israel
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Italy">
#            Italy
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Japan">
#            Japan
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Luxembourg">
#            Luxembourg
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Mexico">
#            Mexico
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Netherlands">
#            Netherlands
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=New+Zealand">
#            New Zealand
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Nigeria">
#            Nigeria
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Norway">
#            Norway
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Pakistan">
#            Pakistan
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Peru">
#            Peru
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Philippines">
#            Philippines
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Portugal">
#            Portugal
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Puerto+Rico">
#            Puerto Rico
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Romania">
#            Romania
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Russia">
#            Russia
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Scotland">
#            Scotland
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Singapore">
#            Singapore
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Somalia">
#            Somalia
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=South+Korea">
#            South Korea
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Spain">
#            Spain
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Sweden">
#            Sweden
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Switzerland">
#            Switzerland
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Taiwan+R.O.C.">
#            Taiwan R.O.C.
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=UK">
#            UK
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=USA">
#            USA
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Uruguay">
#            Uruguay
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Vietnam">
#            Vietnam
#           </a>
#          </li>
#          <li>
#           <a href="/filmguide?country=Wales">
#            Wales
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <div class="col-xs-12 col-sm-9 col-lg-7" id="filmsHolder">
#       <header>
#        <h1>
#         2018  FILM GUIDE
#        </h1>
#        <div class="hidden-xs" id="criteriaTray">
#         <nav style="text-align: center">
#          <a class="texticon" href="/filmguide?letter=a">
#           FESTIVAL GUIDE A TO Z
#          </a>
#          <a class="texticon" href="/filmguide?film_type=Narrative">
#           Narratives
#          </a>
#          <a class="texticon" href="/filmguide?film_type=Documentary">
#           Documentaries
#          </a>
#          <a class="texticon" href="/filmguide?film_duration=Feature">
#           Features
#          </a>
#          <a class="texticon" href="/filmguide?film_duration=Short">
#           Shorts
#          </a>
#          <a class="texticon" href="/filmguide?s_name=TV&amp;section=56e2f788d66728b9e0000001">
#           TV
#          </a>
#          <a class="texticon" href="/filmguide?category=Talk">
#           TALKS
#          </a>
#          <a class="texticon" href="/filmguide?all=1">
#           All Films
#          </a>
#         </nav>
#        </div>
#        <div class="cf" id="displayingTray">
#         <span id="nowShowing">
#          SHOWING 17 FILMS SORTED BY THE LETTER: 'B'
#         </span>
#        </div>
#        <div id="sectionTray">
#         <section class="cf">
#          <div class="left">
#          </div>
#          <div class="right">
#          </div>
#         </section>
#        </div>
#       </header>
#       <article>
#        <section class="infoBlock cf ">
#         <div class="marqueePhoto">
#          <a class="filmImg imageLoader" href="/filmguide/back-roads-2018" loader-style="fade">
#           <img alt="Medium backroads  jarin blaschke  1" src="https://s3.amazonaws.com/tribeca_cms_production/uploads/film/photo_1/5aa9642bdaeedf008742a0dc/medium_BACKROADS__JARIN_BLASCHKE__1.jpg"/>
#          </a>
#         </div>
#         <div class="left">
#          <h1 class="headerTitle">
#           <a href="/filmguide/back-roads-2018">
#            BACK ROADS
#           </a>
#          </h1>
#          <div class="headerTags">
#           <a class="texticon" href="/filmguide/archive?year=2018">
#            TFF 2018
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_type=Narrative">
#            Narrative
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_duration=Feature">
#            Feature
#           </a>
#          </div>
#          <ul class="filmDetails">
#           <li>
#            Section: Spotlight Narrative
#           </li>
#           <li>
#            Release Year: 2018
#           </li>
#           <li>
#            Runtime: 101 minutes
#           </li>
#           <li>
#            Directed By: Alex Pettyfer
#           </li>
#           <li>
#            Country:
#            <a href="/filmguide?country=USA">
#             USA
#            </a>
#           </li>
#          </ul>
#         </div>
#        </section>
#        <section class="synopsis">
#         A young man cares for his sisters after their mother is imprisoned for murdering their abusive father. When he strikes up an affair with a married woman, long-dormant family secrets bubble to the surface in this noir thriller.
#         <a class="readMore" href="/filmguide/back-roads-2018">
#          Read More
#         </a>
#        </section>
#        <section class="genres">
#         <a href="/filmguide?genre=Drama">
#          Drama
#         </a>
#         ,
#         <a href="/filmguide?genre=First+Time+Filmmaker">
#          First Time Filmmaker
#         </a>
#         ,
#         <a href="/filmguide?genre=Female+Screenwriter%28s%29">
#          Female Screenwriter(s)
#         </a>
#        </section>
#       </article>
#       <article>
#        <section class="infoBlock cf ">
#         <div class="marqueePhoto">
#          <a class="filmImg imageLoader" href="/filmguide/bad-peter-2018" loader-style="fade">
#           <img alt="Medium badpeter  noah greenberg  1" src="https://s3.amazonaws.com/tribeca_cms_production/uploads/film/photo_1/5aa96416daeedf0087429ea7/medium_BADPETER__Noah-Greenberg__1.jpg"/>
#          </a>
#         </div>
#         <div class="left">
#          <h1 class="headerTitle">
#           <a href="/filmguide/bad-peter-2018">
#            BAD PETER
#           </a>
#          </h1>
#          <div class="headerTags">
#           <a class="texticon" href="/filmguide/archive?year=2018">
#            TFF 2018
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_type=Narrative">
#            Narrative
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_duration=Short">
#            Short
#           </a>
#          </div>
#          <ul class="filmDetails">
#           <li>
#            Section: Shorts
#           </li>
#           <li>
#            Release Year: 2018
#           </li>
#           <li>
#            Runtime: 9 minutes
#           </li>
#           <li>
#            Directed By: Zach Strauss
#           </li>
#           <li>
#            Country:
#            <a href="/filmguide?country=USA">
#             USA
#            </a>
#           </li>
#          </ul>
#         </div>
#        </section>
#        <section class="synopsis">
#         An expectant mother is forced into a humiliating birthing regimen by her automated personal assistant, which thinks it knows what’s best for her and her unborn child.
#         <a class="readMore" href="/filmguide/bad-peter-2018">
#          Read More
#         </a>
#        </section>
#        <section class="genres">
#         <a href="/filmguide?genre=Comedy">
#          Comedy
#         </a>
#         ,
#         <a href="/filmguide?genre=Drama">
#          Drama
#         </a>
#         ,
#         <a href="/filmguide?genre=Science+Fiction">
#          Science Fiction
#         </a>
#        </section>
#       </article>
#       <article>
#        <section class="infoBlock cf ">
#         <div class="marqueePhoto">
#          <a class="filmImg imageLoader" href="/filmguide/bao-2018" loader-style="fade">
#           <img alt="Medium hold bao  pixaranimationstudios  1920x1080" src="https://s3.amazonaws.com/tribeca_cms_production/uploads/film/photo_1/5aa96439daeedf008742a2b1/medium_HOLD-Bao__PixarAnimationStudios__1920x1080.jpg"/>
#          </a>
#         </div>
#         <div class="left">
#          <h1 class="headerTitle">
#           <a href="/filmguide/bao-2018">
#            BAO
#           </a>
#          </h1>
#          <div class="headerTags">
#           <a class="texticon" href="/filmguide/archive?year=2018">
#            TFF 2018
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_type=Narrative">
#            Narrative
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_duration=Short">
#            Short
#           </a>
#          </div>
#          <ul class="filmDetails">
#           <li>
#            Section: Shorts
#           </li>
#           <li>
#            Release Year: 2018
#           </li>
#           <li>
#            Runtime: 8 minutes
#           </li>
#           <li>
#            Directed By: Domee Shi
#           </li>
#           <li>
#            Country:
#            <a href="/filmguide?country=USA">
#             USA
#            </a>
#           </li>
#          </ul>
#         </div>
#        </section>
#        <section class="synopsis">
#         An empty-nesting Chinese mom gets another chance at motherhood when one of her dumplings springs to life. But she must come to terms with the bittersweet revelation that nothing stays cute and small forever.
#         <a class="readMore" href="/filmguide/bao-2018">
#          Read More
#         </a>
#        </section>
#        <section class="genres">
#         <a href="/filmguide?genre=Animation">
#          Animation
#         </a>
#        </section>
#       </article>
#       <section class="do ad text-center">
#        <div id="div-gpt-ad-1363397367201-0" style="width:640px; height:79px;">
#        </div>
#       </section>
#       <section class="mo ad text-center">
#        <div id="div-gpt-ad-1521603311745-0" style="width:320px; height:50px;">
#        </div>
#       </section>
#       <article>
#        <section class="infoBlock cf ">
#         <div class="marqueePhoto">
#          <a class="filmImg imageLoader" href="/filmguide/bathtubs-over-broadway-2018" loader-style="fade">
#           <img alt="Medium bathtubsoverbroadway  nick higgins  1" src="https://s3.amazonaws.com/tribeca_cms_production/uploads/film/photo_1/5aa9641bdaeedf0087429f2c/medium_BATHTUBSOVERBROADWAY__NICK_HIGGINS__1.jpg"/>
#          </a>
#         </div>
#         <div class="left">
#          <h1 class="headerTitle">
#           <a href="/filmguide/bathtubs-over-broadway-2018">
#            BATHTUBS OVER BROADWAY
#           </a>
#          </h1>
#          <div class="headerTags">
#           <a class="texticon" href="/filmguide/archive?year=2018">
#            TFF 2018
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_type=Documentary">
#            Documentary
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_duration=Feature">
#            Feature
#           </a>
#          </div>
#          <ul class="filmDetails">
#           <li>
#            Section: Special Screenings
#           </li>
#           <li>
#            Release Year: 2018
#           </li>
#           <li>
#            Runtime: 87 minutes
#           </li>
#           <li>
#            Directed By: Dava Whisenant
#           </li>
#           <li>
#            Country:
#            <a href="/filmguide?country=USA">
#             USA
#            </a>
#           </li>
#          </ul>
#         </div>
#        </section>
#        <section class="synopsis">
#         Comedy writer Steve Young’s assignment to scour bargain-bin vinyl for a Late Night segment becomes an unexpected, decades-spanning obsession when he stumbles upon the strange and hilarious world of industrial musicals in this musical-comedy-documentary.
#         <a class="readMore" href="/filmguide/bathtubs-over-broadway-2018">
#          Read More
#         </a>
#        </section>
#        <section class="genres">
#         <a href="/filmguide?genre=New+York">
#          New York
#         </a>
#         ,
#         <a href="/filmguide?genre=Comedy">
#          Comedy
#         </a>
#         ,
#         <a href="/filmguide?genre=Documentary">
#          Documentary
#         </a>
#         ,
#         <a href="/filmguide?genre=Music">
#          Music
#         </a>
#         ,
#         <a href="/filmguide?genre=Female+Director%28s%29">
#          Female Director(s)
#         </a>
#         ,
#         <a href="/filmguide?genre=First+Time+Filmmaker">
#          First Time Filmmaker
#         </a>
#         ,
#         <a href="/filmguide?genre=Female+Screenwriter%28s%29">
#          Female Screenwriter(s)
#         </a>
#        </section>
#       </article>
#       <article>
#        <section class="infoBlock cf ">
#         <div class="marqueePhoto">
#          <a class="filmImg imageLoader" href="/filmguide/battlescar-2018" loader-style="fade">
#           <img alt="Medium battlescar 1" src="https://s3.amazonaws.com/tribeca_cms_production/uploads/film/photo_1/5aa96441daeedf008742a3ab/medium_BattleScar_1.jpg"/>
#          </a>
#         </div>
#         <div class="left">
#          <h1 class="headerTitle">
#           <a href="/filmguide/battlescar-2018">
#            BATTLESCAR
#           </a>
#          </h1>
#          <div class="headerTags">
#           <a class="texticon" href="/filmguide/archive?year=2018">
#            TFF 2018
#           </a>
#          </div>
#          <ul class="filmDetails">
#           <li>
#            Section: Virtual Arcade
#           </li>
#           <li>
#            Release Year: 2018
#           </li>
#           <li>
#            Runtime: 9 minutes
#           </li>
#           <li>
#            Country:
#            <a href="/filmguide?country=USA">
#             USA
#            </a>
#            ,
#            <a href="/filmguide?country=France">
#             France
#            </a>
#           </li>
#          </ul>
#         </div>
#        </section>
#        <section class="synopsis">
#         After Lupe, a Puerto Rican runaway, meets Debbie in the cell of a juvenile detention center, she is introduced to the punk scene of the Lower East Side and the secret world of Alphabet City.
#         <em>
#          BattleScar
#         </em>
#         is a coming of age drama set in 1978 New York that explores identity and empowerment through stunning animation and immersive environments.
#         <a class="readMore" href="/filmguide/battlescar-2018">
#          Read More
#         </a>
#        </section>
#        <section class="genres">
#         <a href="/filmguide?genre=New+York">
#          New York
#         </a>
#         ,
#         <a href="/filmguide?genre=Animation">
#          Animation
#         </a>
#         ,
#         <a href="/filmguide?genre=Latino+Director%28s%29">
#          Latino Director(s)
#         </a>
#        </section>
#       </article>
#       <article>
#        <section class="infoBlock cf ">
#         <div class="marqueePhoto">
#          <a class="filmImg imageLoader" href="/filmguide/bethany-hamilton-unstoppable-2018" loader-style="fade">
#           <img alt="Medium bethany hamilton   unstoppable aaron lieber 02 1920x1080" src="https://s3.amazonaws.com/tribeca_cms_production/uploads/film/photo_1/5aa9642edaeedf008742a151/medium_BETHANY-HAMILTON---UNSTOPPABLE_AARON_LIEBER_02-1920x1080.png"/>
#          </a>
#         </div>
#         <div class="left">
#          <h1 class="headerTitle">
#           <a href="/filmguide/bethany-hamilton-unstoppable-2018">
#            BETHANY HAMILTON: UNSTOPPABLE
#           </a>
#          </h1>
#          <div class="headerTags">
#           <a class="texticon" href="/filmguide/archive?year=2018">
#            TFF 2018
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_type=Documentary">
#            Documentary
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_duration=Feature">
#            Feature
#           </a>
#          </div>
#          <ul class="filmDetails">
#           <li>
#            Section: Spotlight Documentary
#           </li>
#           <li>
#            Release Year: 2018
#           </li>
#           <li>
#            Runtime: 98 minutes
#           </li>
#           <li>
#            Directed By: Aaron Lieber
#           </li>
#           <li>
#            Country:
#            <a href="/filmguide?country=USA">
#             USA
#            </a>
#           </li>
#          </ul>
#         </div>
#        </section>
#        <section class="synopsis">
#         One of the most fearless and accomplished athletes of her generation, Bethany Hamilton became a surfing wunderkind when she returned to the sport following a devastating shark attack at age 13. Now she faces her biggest challenge yet: motherhood.
#         <a class="readMore" href="/filmguide/bethany-hamilton-unstoppable-2018">
#          Read More
#         </a>
#        </section>
#        <section class="genres">
#         <a href="/filmguide?genre=Documentary">
#          Documentary
#         </a>
#         ,
#         <a href="/filmguide?genre=Sports">
#          Sports
#         </a>
#         ,
#         <a href="/filmguide?genre=First+Time+Filmmaker">
#          First Time Filmmaker
#         </a>
#        </section>
#       </article>
#       <article>
#        <section class="infoBlock cf ">
#         <div class="marqueePhoto">
#          <a class="filmImg imageLoader" href="/filmguide/big-elvis-2018" loader-style="fade">
#           <img alt="Medium big elvis  pete vallee collection  1" src="https://s3.amazonaws.com/tribeca_cms_production/uploads/film/photo_1/5aa96423daeedf0087429ff7/medium_BIG-Elvis-_Pete-Vallee-Collection_-1.jpg"/>
#          </a>
#         </div>
#         <div class="left">
#          <h1 class="headerTitle">
#           <a href="/filmguide/big-elvis-2018">
#            BIG ELVIS
#           </a>
#          </h1>
#          <div class="headerTags">
#           <a class="texticon" href="/filmguide/archive?year=2018">
#            TFF 2018
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_type=Documentary">
#            Documentary
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_duration=Short">
#            Short
#           </a>
#          </div>
#          <ul class="filmDetails">
#           <li>
#            Section: Shorts
#           </li>
#           <li>
#            Release Year: 2018
# ...
#         <a class="readMore" href="/filmguide/biidaaban-first-light-2018">
#          Read More
#         </a>
#        </section>
#        <section class="genres">
#         <a href="/filmguide?genre=Experimental">
#          Experimental
#         </a>
#         ,
#         <a href="/filmguide?genre=Female+Director%28s%29">
#          Female Director(s)
#         </a>
#        </section>
#       </article>
#       <article>
#        <section class="infoBlock cf ">
#         <div class="marqueePhoto">
#          <a class="filmImg imageLoader" href="/filmguide/black-label-2018" loader-style="fade">
#           <img alt="Medium black label  roger llonch  1" src="https://s3.amazonaws.com/tribeca_cms_production/uploads/film/photo_1/5aa96416daeedf0087429ea0/medium_Black-Label__Roger-Llonch__1.jpg"/>
#          </a>
#         </div>
#         <div class="left">
#          <h1 class="headerTitle">
#           <a href="/filmguide/black-label-2018">
#            BLACK LABEL
#           </a>
#          </h1>
#          <div class="headerTags">
#           <a class="texticon" href="/filmguide/archive?year=2018">
#            TFF 2018
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_type=Narrative">
#            Narrative
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_duration=Short">
#            Short
#           </a>
#          </div>
#          <ul class="filmDetails">
#           <li>
#            Section: Shorts
#           </li>
#           <li>
#            Release Year: 2017
#           </li>
#           <li>
#            Runtime: 11 minutes
#           </li>
#           <li>
#            Directed By: David Vergés
#           </li>
#           <li>
#            Country:
#            <a href="/filmguide?country=Spain">
#             Spain
#            </a>
#           </li>
#          </ul>
#         </div>
#        </section>
#        <section class="synopsis">
#         Erik is a night-shift employee from a lonely gas station; Alex is a regular at the shop. One night, something happens that gives them the opportunity to discover who they really are.
#         <a class="readMore" href="/filmguide/black-label-2018">
#          Read More
#         </a>
#        </section>
#        <section class="genres">
#         <a href="/filmguide?genre=Comedy">
#          Comedy
#         </a>
#        </section>
#       </article>
#       <article>
#        <section class="infoBlock cf ">
#         <div class="marqueePhoto">
#          <a class="filmImg imageLoader" href="/filmguide/bleeding-edge-2018" loader-style="fade">
#           <img alt="Medium thebleedingedge 1920x1080" src="https://s3.amazonaws.com/tribeca_cms_production/uploads/film/photo_1/5aa9642cdaeedf008742a0fc/medium_TheBleedingEdge-1920x1080.jpg"/>
#          </a>
#         </div>
#         <div class="left">
#          <h1 class="headerTitle">
#           <a href="/filmguide/bleeding-edge-2018">
#            THE BLEEDING EDGE
#           </a>
#          </h1>
#          <div class="headerTags">
#           <a class="texticon" href="/filmguide/archive?year=2018">
#            TFF 2018
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_type=Documentary">
#            Documentary
#           </a>
#           <a class="texticon" href="/filmguide/archive?film_duration=Feature">
#            Feature
#           </a>
#          </div>
#          <ul class="filmDetails">
#           <li>
#            Section: Spotlight Documentary
#           </li>
#           <li>
#            Release Year: 2018
#           </li>
#           <li>
#            Runtime: 99 minutes
#           </li>
#           <li>
#            Directed By: Kirby Dick
#           </li>
#           <li>
#            Country:
#            <a href="/filmguide?country=USA">
#             USA
#            </a>
#           </li>
#          </ul>
#         </div>
#        </section>
#        <section class="synopsis">
#         Each year in the United States, unparalleled innovations in medical diagnostics, treatment, and technology hit the market.  But when the same devices designed to save patients end up harming them, who is accountable?
#         <a class="readMore" href="/filmguide/bleeding-edge-2018">
#          Read More
#         </a>
#        </section>
#        <section class="genres">
#         <a href="/filmguide?genre=Environmental">
#          Environmental
#         </a>
#        </section>
#       </article>
#       <nav class="pagination cf">
#        <div class="linksbar">
#         <span class="page# current">
#          1
#         </span>
#         <span class="page#">
#          <a href="/filmguide?letter=b&amp;page=2" rel="next">
#           2
#          </a>
#         </span>
#        </div>
#        <span class="next">
#         <a href="/filmguide?letter=b&amp;page=2" rel="next">
#          <span>
#           &gt;
#          </span>
#         </a>
#        </span>
#       </nav>
#      </div>
#      <div class="col-xs-12 col-lg-3 text-center">
#       <div class="row">
#        <div class="col-xs-12 col-sm-6 col-lg-12">
#         <a class="barBtn" href="https://s3.amazonaws.com/tribeca_cms_production/uploads/document/document/5ad5fcd7daeedf4939172c86/FINAL_FIP_PUBLIC.pdf" target="_blank">
#          <img alt="Graphic fg pdf" src="/assets/graphic-fg-pdf-08068967d8c34544d8bfc9b1b2fe6d118636e2ab4c523e4a129eaec7c4a754db.png"/>
#         </a>
#         <div id="div-gpt-ad-1363397367201-2" style="width:300px; height:250px;">
#         </div>
#         <br/>
#         <br/>
#        </div>
#        <div class="col-xs-12 col-sm-6 col-lg-12">
#         <div id="div-gpt-ad-1365726183346-0" style="width:300px; height:250px;">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="" id="footerAd">
#     <div class="cw">
#      <div class="ad728_215 cf">
#       <div class="left">
#        <div id="div-gpt-ad-1364494985785-0" style="width:728px; height:90px;">
#        </div>
#       </div>
#       <!-- ROS_215x90_Footer -->
#       <div class="right" id="div-gpt-ad-1365099204269-0" style="width:215px; height:90px;">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="rushbox">
#     <h2>
#      RUSH SALES POLICY
#     </h2>
#     <p>
#      When tickets for a screening or event are no longer available, they will be listed as RUSH. The Rush system functions as a stand-by line that will form at the venue approximately 45 minutes prior to scheduled start time. Admittance is based on availability and will begin 15 minutes prior to program start time. Rush Tickets are the same price as advance tickets payable upon entry. There is a limit of one Rush Ticket per person.
#     </p>
#    </div>
#    <footer id="mainFooter">
#     <div class="cw">
#      <div class="cf" id="footSocial">
#       <section class="row cf">
#        <div id="footerLogo">
#         <a class="ir" href="/">
#          Tribeca
#         </a>
#        </div>
#        <nav>
#         <a href="https://www.facebook.com/Tribeca" target="_blank">
#          <i class="fa fa-facebook fa-2x">
#          </i>
#         </a>
#         <a href="http://twitter.com/tribeca" target="_blank">
#          <i class="fa fa-twitter fa-2x">
#          </i>
#         </a>
#         <a href="http://instagram.com/tribeca" target="_blank">
#          <i class="fa fa-instagram fa-2x">
#          </i>
#         </a>
#         <a href="http://tribeca.tumblr.com" target="_blank">
#          <i class="fa fa-tumblr fa-2x">
#          </i>
#         </a>
#         <a href="http://www.youtube.com/tribecafilm" target="_blank">
#          <i class="fa fa-youtube fa-2x">
#          </i>
#         </a>
#         <a href="http://tribecafilm.com/feed.xml" target="_blank">
#          <i class="fa fa-rss fa-2x">
#          </i>
#         </a>
#        </nav>
#       </section>
#      </div>
#      <div class="cf" id="footLinks">
#       <section class="row cf">
#        <nav class="col">
#         <header>
#          MORE INFO
#         </header>
#         <a href="/sponsorship">
#          Partnership
#         </a>
#         <a href="/festival/industry">
#          Industry
#         </a>
#         <a href="/contact">
#          Contact
#         </a>
#         <a href="/festival/jobs">
#          Jobs/Crew
#         </a>
#         <a href="/code-of-conduct">
#          CODE OF CONDUCT
#         </a>
#        </nav>
#        <nav class="col">
#         <header>
#          AFFILIATES
#         </header>
#         <a href="http://www.tribecafilminstitute.org/" target="_blank">
#          Tribeca Film Institute®
#         </a>
#         <a href="https://www.tribecaflashpoint.edu/" target="_blank">
#          Tribeca Flashpoint
#         </a>
#         <a href="http://www.tribecafilmcenter.com/" target="_blank">
#          Tribeca Film Center®
#         </a>
#         <a href="http://www.tribecadisruptiveinnovationawards.com/" target="_blank">
#          Tribeca Disruptive Innovation
#         </a>
#        </nav>
#        <nav class="col">
#         <header>
#          PRESS CENTER
#         </header>
#         <a href="/press-center">
#          Press Home
#         </a>
#         <a href="/press-center/festival">
#          Film Festival Press
#         </a>
#         <a href="https://tribecafilminstitute.org/press_releases" target="_blank">
#          TFI Press
#         </a>
#        </nav>
#       </section>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <script>
#    var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
#
#   googletag.cmd.push(function() {
#
#         googletag.defineSlot('/42447178/Leaderboardtest1', [640, 79], 'div-gpt-ad-1363397367201-0').addService(googletag.pubads());
#     googletag.defineSlot('/42447178/320x50', [320, 50], 'div-gpt-ad-1521603311745-0').addService(googletag.pubads());
#     googletag.defineSlot('/42447178/leaderboardtest2', [640, 79], 'div-gpt-ad-1363397367201-1').addService(googletag.pubads());
#     googletag.defineSlot('/42447178/rectangle300test', [300, 250], 'div-gpt-ad-1363397367201-2').addService(googletag.pubads());
#     googletag.defineSlot('/42447178/filmguide300x2', [300, 250], 'div-gpt-ad-1365726183346-0').addService(googletag.pubads());
#               googletag.defineSlot('/42447178/Footer_728x90', [728, 90], 'div-gpt-ad-1364494985785-0').addService(googletag.pubads());
#           googletag.defineSlot('/42447178/ROS_215x90_Footer', [215, 90], 'div-gpt-ad-1365099204269-0').addService(googletag.pubads());
#
#
#     // googletag.pubads();
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-10764567-1', 'auto');
#   ga('require', 'linkid', 'linkid.js');
#
#
#   ga('send', 'pageview');
#   </script>
#   <div id="fb-root">
#   </div>
#   <script>
#    (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&appId=232295416876278&version=v2.0";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <script src="/assets/application-963c7aded5c2227201d70342560bc9179544fc88fcc90e7bac6bcdb2fe6974bd.js">
#   </script>
#   <script src="/assets/main-b9d24c56d6f4d5586e0108fb3782edb3f8088bf76e024592a4ed9d628a96e302.js">
#   </script>
#   <script src="/assets/wishlist/wishlist_main-400d7b7667a111b5d914ccf369e1246a39d1e1c5e9cd946ea25eacf416f3cb42.js">
#   </script>
#   <script>
#    $("#filters").accordion({
#   active: 0,
#   animate: 0,
#   collapsible: true
# })
#
# var $accordion = $('#filters .js-item');
# $accordion.click(function () {
#   var $this = $(this);
#   if ($this.hasClass('active')) {
#     $this.removeClass('active').find('i').removeClass('fa-minus').addClass('fa-plus');
#   } else {
#     $accordion.removeClass('active');
#     $this.addClass('active');
#     $accordion.find('i').removeClass('fa-minus').addClass('fa-plus');
#     $this.find('i').addClass('fa-minus')
#   }
# });
#   </script>
#   <script type="text/javascript">
#    googletag.cmd.push(function() { googletag.display('div-gpt-ad-1363397367201-0'); });
#   </script>
#   <script type="text/javascript">
#    googletag.cmd.push(function() { googletag.display('div-gpt-ad-1521603311745-0'); });
#   </script>
#   <script type="text/javascript">
#    googletag.cmd.push(function() { googletag.display('div-gpt-ad-1363397367201-1'); });
#   </script>
#   <script type="text/javascript">
#    googletag.cmd.push(function() { googletag.display('div-gpt-ad-1363397367201-2'); });
#   </script>
#   <script type="text/javascript">
#    googletag.cmd.push(function() { googletag.display('div-gpt-ad-1365726183346-0'); });
#   </script>
#   <script type="text/javascript">
#    googletag.cmd.push(function() { googletag.display('div-gpt-ad-1364494985785-0'); });
#   </script>
#   <script type="text/javascript">
#    googletag.cmd.push(function() { googletag.display('div-gpt-ad-1365099204269-0'); });
#   </script>
#   <script>
#    $(function() {
#       $('.rushTrigger').fancybox();
#     });
#   </script>
#   <script>
#    var app = app || {};
# app.gb = function (){
#   $(".infoBlock").each(function(){var a=$(this),o=_.random(1,21);if(a.hasClass("noPhoto")){var s=a.find(".headerTitle a").attr("href");a.removeClass("noPhoto").prepend("<div class='marqueePhoto'><a href='"+s+"' class='filmImg' loader-style='fade'><img src=''/></a></div>")}a.find(".filmImg img").attr("src","https://tribeca_cms_production.s3.amazonaws.com/gb/"+o+".gif")});$('a[href^="/filmguide?"]').each(function(_,e){e.href = e.href+"#blumme";})
# }
#
# $(function() {
#   $('#loadMore').on('click', function(e){
#     e.preventDefault();
#     var getMore = $('#moreHeaderStripe').data("link");
#     $.get(getMore+'.html', function(data){
#       $('#moreHolder').append(data);
#     });
#   });
#
#   $('#thumbTray .info').tipsy({title: function() {
#     if($(this).hasClass('watchlist')) {
#       return $('#watchTip').html();
#     } else if ($(this).hasClass('sharethis')) {
#       return $('#shareTip').html();
#     }
#   }, gravity: 'w', html:true});
#
#   $('.collapser').on('click', function(e){
#     var drawer = $(e.target).parents('.collapsible');
#     if($(drawer).hasClass('closed')) {
#       $(e.target).html("Collapse");
#       $(drawer).removeClass('closed').children('.drawer').slideDown(200);
#     } else {
#       $(e.target).html("Expand");
#       $(drawer).addClass('closed').children('.drawer').slideUp(200);
#     }
#   });
#
#   $('.screenings').on('click', '.noteTrigger', function(e) {
#     e.stopPropagation();
#     $(this).closest('tr').next('.note').toggle();
#   })
#
#   $('table.screenings .limited')
#     .mouseenter(function(e){
#       $(this).data('price', $(this).html()).html('LIMITED');
#     }).mouseleave(function(e){
#       $(this).html($(this).data('price'));
#     });
#   if ( window.location.hash === "#blumme" ) app.gb();
# });
#   </script>
#   <script>
#    $(function(){
#       var WISHLIST = window.WISHLIST || {};
#           WISHLIST.not_logged_in = true;
#     });
#   </script>
#   <script type="application/ld+json">
#    {
#       "@context": "http://schema.org",
#       "@type": "Organization",
#       "name" : "Tribeca",
#       "url": "https://tribecafilm.com",
#       "logo": "https://tribecafilm.com/assets/logo-meta.png",
#       "sameAs" : [
#         "https://www.facebook.com/Tribeca",
#         "https://twitter.com/tribeca",
#         "https://www.instagram.com/tribeca",
#         "http://tribeca.tumblr.com",
#         "https://www.youtube.com/user/tribecafilm"
#       ],
#       "potentialAction": {
#         "@type": "SearchAction",
#         "target": "https://tribecafilm.com/browse?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#       }
#     }
#   </script>
#  </body>
# </html>

# %% [markdown]
# The goal is pull out as much information as you can for each film from both pages films that start with B.
#
# Ideally you want to end up with a list of dictionaries. But a list of lists is fine.

# %%
#To start, see if you can get a list of all movie names
#If so, this is what you will loop throug to get all the information

# %%
#first isolate the info for the first movie

# %%
#If you can get that info put it in a list or dictionary

# %%
#Test the same approach next movie

# %%
#If that works try to loop through all the movies
#fill in a list with a list/dictionary for each movie

# %%
#If that works, scrape the link to the next page

# %%
#Take that link and try to scrape next page with the same code
