# %% [markdown]
# ## homework 4: part two: investigating lists and dictionaries using functions
#
# In this assignment I will ask you to pick five relatively short texts (poems, paragraphs, short essays, song lyrics, whatever interests you). The main thing is to make sure that each text is around 10 - 20 lines or sentences long. Below, I have selected five poems by Wallace Stevens. In each cell I have made a variable that contains each poem, and then I pass that poem through a function called `text_to_dict` that makes a dictionary for each poem. The dictionary contains the title of the poem, the full text as one string, and a list that contains each line of the poem. The function will also make lists of sentences instead of lines if you want to investigate a prose text (sentence by sentence) instead of a poem (line by line).
#
# There are two parts of this assignment.
#
# **Part 1**, which should be easy, is to replace the poems with texts of your own choice--and choose to split them by lines or sentences.
#
# **Part 2** is to write functions that and investigate your texts. If you want to focus on the functions first, you can go straight to Part 2 and use the pomes I have chosen. You can then go back and enter your own texts--your functions should work no matter what text you've chosen.

# %%
#Run this cell toImport regular expressions
#And to initialize the all texts list that will contain all of your dictionaries of text
import re
all_texts = []

# %% [markdown]
# ** understanding the text_to_dict function**
#
# You don't have to completely understand this function to use it, but you do need to understand its parameters. It takes three parameters:
# * `title` is a string you need to write inside function's parameters
# * `text` is the variable that holds the entire text
# * `poem` True/False parameter --if it is true it will split your text by line (`\n`)
#  	If it is false it will split your text by sentence ('[.?!])
#
# If you look at the function you will see that it builds a dictionary with the following fields:
# * `title` is the title of the text
# * `text_as_string` is the full text as a string
# * `lines` is a list of lines or sentences
#
# It returns a dictionary with those fields.

# %%
def text_to_dict(title,text,poem):
    dict_of_this_text = {}
    dict_of_this_text['title'] = title
    dict_of_this_text['text_as_string'] = text
    if poem:
        text_to_list = text.strip().split('\n')
    else:
        text_to_list = re.split(r"[.?!]",text)
    dict_of_this_text['lines'] = text_to_list
    return dict_of_this_text

# %% [markdown]
# ## Part One
#
# The next five cells are exactly the same. They define five different texts, and then they pass each text through the `text_to_dict` function. And then they add the resulting dictionary to the all_texts list.
#
# In the five cells below enter your five selected texts.
#
# **You should do no coding at any point** until the very last cell before part two.

# %%
#To change the text, just put a new text between the quotation mark
text0 = '''
Pearl, to delight a prince's day,
Flawlessly set in gold so fair
In all the East, I dare to say,
I have not found one to compare.
So round, so radiant in array,
So small, so smooth her contours were,
Wherever I judged jewels gay
I set her worth as truly rare.
I lost her in a garden where
Through grass she fell to earthen plot;
Wounded by love beyond repair
I mourn that pearl without a spot.
Since from that spot it fled that day
I waited oft, in hope to see
What once could drive my gloom away
And charge my very soul with glee;
But heavy on my heart it lay
And filled my breast with misery.
Yet no song ever seemed so gay
As that quiet hour let steal to me
Though in my heart one thought ran free,
Her fresh face wrapped in earthly clot;
Earth, you have marred her purity,
My secret pearl without a spot.

That spot of spices needs must spread
Where such rich bounty doth decay,
With yellow flowers and blue and red
That shine so bright in sun's clear ray.
Flower and fruit can ne'er be dead
Where that pearl slipped into the clay,
For grass will grow from seed once shed
Or grain could not be stored away,
And good will always good repay.
This comely seed shall perish not,
And spices will their fruit display
From that dear pearl without a spot.
From that spot I in speech expound
I entered in that garden green,
As August's season came around
When corn is cut with sickles keen,
There that pearl rolled into the ground,
Shadowed with plants both bright and clean,
Wallflower, ginger, gromwell abound
Bright peonies scattered in between;
Though they were seemly to be seen
No less in their scent my sense caught;
And there that jewel long has been,
My precious pearl without a spot.

Before that spot I clasped my hand,
In chilling care my heart was caught;
A bitter grief my soul unmanned
Though reason wiser comfort sought.
I mourned my pearl from freedom banned
With arguments that fiercely fought;
Though Christ's grace bade me understand
My wretched will fresh sorrow brought.
On flowery sward I fell, distraught;
Such fragrance to my senses shot
In deepest sleep I dreamt, methought,
On that dear pearl without a spot.
'''
#Remember: you need to type the title into the first parameter
#If you want to split by line choose True for the third parameter
#If you want to split by sentence, choose False
transform_it = text_to_dict("Pearl, Part I",text0,True)
all_texts.append(transform_it)

# %%
text1 = '''
That spot my spirit fled apace
And let my body dreaming lie.
My soul set forth in God's good grace
To range where marvels multiply.
In all this world I knew no place
Like this, where such cliffs clove the sky.
Towards the woods I turned my face,
Where splendid rocks I could descry.
None could believe aught could supply
Such gleaming glory to the sight;
No fabric that men weave could vie
With all that glorious splendour bright

In splendour shone those downland sides
Clear did those cliffs their nature show,
And, bright about them, woodland rides
With tree-trunks blue as indigo;
Like silver, each leave open slides
And gently flickers to and fro;
When broken cloud above them glides
With shimmering sheen I see them glow.
The gravel on the ground below
Was precious pearls of Orient light;
The sunlight's beams could scarcely show
Against that glorious splendour bright.
The splendour of those bright hills there
My spirit freed from my side fate;
Refreshing was the fragrance clear
Of fruits, as though of food I ate;
Birds flew in all the woodland near
Of myriad hue, both small and great,
Cytole and cithern none could hear
To match a sound so delicate;
The notes their wing-beats did create
Made sounds of such sweet delight
Such charm no man could fabricate,
As here in all their splendour bright.

The splendour bright of that display,
The wood where fortune smiled on me,
The glory thereof to portray
No man could render worthily.
I wandered joyful on my way;
No height could do me injury.
As through the woods my footsteps stray
Field, shrub, and spice, and each pear-tree,
Hedgerow and stream and banks I see
Like gold thread shines each wooded height;
I came to a streamlet running free;
Lord, glorious was that splendour bright !
The splendour of the water deep
Was lovely banks of beryl clear
And sweetly did that water sweep,
Flowing with murmuring sound anear.
Its depths each standing stone did steep,
And, as through glass, bright gleams appear
As streaming stars, when mortals sleep,
Sine in the heavens when winter's here;
Each pebble in that sparkling mere,
Emerald and sapphire, all unite;
Its glowing radiance without peer,
So dear to me that splendour bright.
'''
transform_it = text_to_dict("Pearl, Part II",text1,True)
all_texts.append(transform_it)

# %%
text2 = '''
The splendour of those downs and dales,
Of woods and water, lovely plains
Increased my joy, soothed my travails,
Removed all stress, destroyed all pains.
Beside a stream that never fails
In bliss I travel; naught restrains
My onward journey through those vales;
The greater joy my heart contains.
As fortune at her whim constrains,
And solace sends, or trials sore,
So he who profits from these gains
Desires her favours more and more.

And still more joy came in a trice
Than I, though had I time, could say
For earthly heart would not suffice
One tenth my pleasure to convey;
Because it seemed that Paradise
Perchance beyond those mountains lay;
I thought the stream a mere device
To join the pools and gardens gay;
Beyond the stream, in some strange way,
Some city lay spread out before.
The stream was deep; fear bade me stay,
Yet longing filled me more and more

More and more and yet more still
I longed to see that other side;
If this bank could such joy instill
Still lovelier sights that shore supplied.
I stood and stared against my will;
At once to find a ford I tried,
But felt something threatened ill
The more I walked that brook beside.
'Gainst further progress reason cried
Though such delights might lie in store;
A newer thing I then espied
That moved my senses more and more.
More marvels to my sense repair
I looked and saw yet more anon,
A crystal cliff resplendent there
With royal rays of splendour shone;
And at its foot a child so fair
More courtly maiden there was none.
A gleaming mantle she did wear;
I knew her well from times long gone,
Like gold that craftsmen work upon
So shone that maid upon that shore,
And long my eyes did linger on
That maid, and knew her more and more.

The more I scanned that lovely face,
That lovely form so long unseen,
Such gladness did my soul embrace
As in my life had never been.
My need to call her grew apace;
I wondered what this thing might mean;
To see her in so strange a place
Might deal my heart a blow too keen.
She raised her head; her face was clean
As polished ivory, I swore;
Shaken by things so unforeseen,
I longed to see her more and more
'''
transform_it = text_to_dict("Pearl, Part III",text2,True)
all_texts.append(transform_it)

# %%
all_texts[1]['title']
# Out:
# 'Pearl, Part II'

# %%
text3 = '''
Against my will arose more fear;
I stood stock still and dared not call.
With mouth set fast, but eye still not clear
I stood as still as a hawk in hall.
I thought her purpose spiritual cheer
And yet I feared what might befall,
That she might stop ere I drew near
And might escape me after all;
That gracious girl, so smooth, so small,
So free of stain, so seeming slight,
Royally clad, rose up withal,
A precious maid in pearls bedight.

With pearls bedight most royally
There by God's grace might now be seen,
When she, as fresh as fleur-de-lys,
Came straightaway down to the bank between,
Her linen gleaming white I see,
Open at sides, bright with a sheen
Of lovelier pearls, it seemed to me
Than in my sight had ever been;
With hanging sleeves so wide and clean
And double rows of pearls so bright
Her kirtle matched that lovely scene,
With precious pearls richly bedight.
Bedight with pearls her crown arrayed;
With pearls and with no other stone,
High-pinnacled in pearls displayed
With figured flowers thereupon,
And on her head no covering laid.
Her face enclosèd round; as one
Like duke or earl her look was staid;
Her features white as whalebone shone;
Like burnished gold her tresses on
Her shoulders, all unbound, lay light;
Their hue defied comparison
With wimple's edge in pearls bedight.

Bedight with pearls at every hem
Of wrists, hands, sides and throat I saw;
With whitest pearl, no other gem,
And gleaming white the dress she wore;
Richer than any diadem
A pearl upon her breast she bore;
No man might praise it or condemn,
Its worth would surely overawe.
I judge no tongue e'er found before 
Words to describe that glorious sight,
So clean it was, so clear, so pure.
That precious pearl there so bedight.
Bedight in pearls, that precious piece
From that far bank came to the shore.
No happier man from here to Greece
To see her stand the brink before.
She was more close than aunt or niece;
And therefore was my joy the more.
The fairest words she did release,
Bowed low as e'er she did of yore,
Removed her crown of richest store
And hailed me with a sweet delight,
Well for the man my mother bore
To greet that maid in pearls bedight !

'O Pearl,' I said, 'in pearls bedight,
Are you my pearl for whom I cried,
For whom I grieved alone at night ?
Much longing I for you have sighed
Since into grass you left my sight.
Sorrow and grief with me reside
While you remain in true delight
In Paradise, in peace to abide.
What fate did now my pearl betide
And left me here in grief and care ?
Since you were severed from my side
I am a joyless jeweller.'
That jewel then in gems arrayed
Lifted to me those eyes of grey,
And donned her crown, of jewels made,
And gravely then I heard her say:
'Sir, your conclusion is mislaid
To say your pearl has fled away,
That is in such a casket laid
As in this gracious garden gay,
To dwell in joy in endless day;
Never can loss or grief come near.
No pearl in such a casket lay,
'Twould seem, for any jeweller.'

'But, jeweller kind, if you must lose
Your joy in a gem to you so dear,
I think you do yourself confuse,
Your thought short-lived, your view unclear.
She was a rose which could not choose
But bloom and fade by laws austere.
The casket naturally endues
The pearl it holds with worth most clear.
And yet you call your fate severe
When much from naught was offered there;
The cure you curse lay always near,
You most unnatural jeweller.'
A jewel was this maid to me
And jewels were her noble speech.
'Indeed,' I said, 'most happily
In my distress you make a breach;
May my great fault forgiven be !
I thought my pearl far out of reach
Now I have found it, great my glee;
I'Il dwell in woods of oak and beech,
And love the laws my Lord doth teach
That have provided joys sincere.
And if yon bank I now could reaeh,
I'd be a joyful jeweller.'

Jeweller,' said this gern sublime,
'You jest ! You lack all sanity !
Three words you utter at one time;
Ill-judged, in truth, were they all three.
Your thought no reason has nor rhyme;
Your words before your thoughts run free.
You say that you believe that I'm
Lodged in this vale, for that you see;
And then you say, in this country
That you can dwell with me right here;
Third, you may cross the stream to me-
That may no joyful jeweller.'
'''
transform_it = text_to_dict("Pearl, Part IV",text3,True)
all_texts.append(transform_it)

# %%
text4 = '''
'I give that jeweller little praise
Who trusts the witness of his eye,
And much to blame, and lacking grace,
Who thinks our Lord would make a lie,
Who faithfully swore your soul to raise,
Though fate decreed your flesh should die.
You set his words in crooked ways
Accepting naught your eyes deny.
That is a proof of pride too high,
With which no good man could agree,
Accepting naught he cannot try
Unless his judgement so decree.'

'Judge for yourself if, as a man,
Such words to God you e'er should say.
You think to dwell here, if you can,
First you must needs ask if you may.
And you will learn there is a ban;
To cross this stream without delay
Offends against the heavenly plan.
First, you must sink into the clay;
In Eden, man dared disobey
Because he lacked humility;
Now man through death must make his way
For God so judged. 'Tis his decree.
Am I then judged,' I said, 'my sweet,
To grieve again? Then I must pine;
To find, then lose, is loss complete.
Must I accept, my life consign
To loss and death? It is not meet
That you, my pearl, make me repine;
Gain that brings tears is mere deceit.
If I must now myself resign,
I care not how low I decline
Nor how far hence I now must flee;
My pearl is lost that once was mine,
Such judgement sorrow must decree.

'You judge this nothing but distress,'
Then said that maid, 'Why do you so ?
He who concerns himself with less
Must thoughts of greater loss forgo.
Remember Him who lives to bless,
And still love God, come weal or woe.
Do not complain when, comfortless,
You wax impatient, for, although
You leap as high as any doe
And writhe and moan in agony,
When you can then no further go
Abide His judgement, His decree.
If you judge Him, and Him accuse,
He will not turn one step aside;
His recompense you then will lose;
Your sorrow then you must abide.
Cease all your wrangling and abuse
And in His mercy still confide.
Compassion he will not refuse,
His power thus is magnified.
For, though you grieve, and seek to hide
The depth of all your misery,
His grace is ever by your side,
And He will judge. 'Tis His decree.'
'''
transform_it = text_to_dict("Pearl, Part VI",text4,True)
all_texts.append(transform_it)

# %% [markdown]
# Run the two cells below to confirm that first, you only have five texts in the all_texts list, and next, look at the all_texts list to see the dictionary inside it.

# %%
len(all_texts)
# Out:
# 5

# %%
all_texts
# Out:
# [{'lines': ["Pearl, to delight a prince's day,",
#    'Flawlessly set in gold so fair',
#    'In all the East, I dare to say,',
#    'I have not found one to compare.',
#    'So round, so radiant in array,',
#    'So small, so smooth her contours were,',
#    'Wherever I judged jewels gay',
#    'I set her worth as truly rare.',
#    'I lost her in a garden where',
#    'Through grass she fell to earthen plot;',
#    'Wounded by love beyond repair',
#    'I mourn that pearl without a spot.',
#    'Since from that spot it fled that day',
#    'I waited oft, in hope to see',
#    'What once could drive my gloom away',
#    'And charge my very soul with glee;',
#    'But heavy on my heart it lay',
#    'And filled my breast with misery.',
#    'Yet no song ever seemed so gay',
#    'As that quiet hour let steal to me',
#    'Though in my heart one thought ran free,',
#    'Her fresh face wrapped in earthly clot;',
#    'Earth, you have marred her purity,',
#    'My secret pearl without a spot.',
#    '',
#    'That spot of spices needs must spread',
#    'Where such rich bounty doth decay,',
#    'With yellow flowers and blue and red',
#    "That shine so bright in sun's clear ray.",
#    "Flower and fruit can ne'er be dead",
#    'Where that pearl slipped into the clay,',
#    'For grass will grow from seed once shed',
#    'Or grain could not be stored away,',
#    'And good will always good repay.',
#    'This comely seed shall perish not,',
#    'And spices will their fruit display',
#    'From that dear pearl without a spot.',
#    'From that spot I in speech expound',
#    'I entered in that garden green,',
#    "As August's season came around",
#    'When corn is cut with sickles keen,',
#    'There that pearl rolled into the ground,',
#    'Shadowed with plants both bright and clean,',
#    'Wallflower, ginger, gromwell abound',
#    'Bright peonies scattered in between;',
#    'Though they were seemly to be seen',
#    'No less in their scent my sense caught;',
#    'And there that jewel long has been,',
#    'My precious pearl without a spot.',
#    '',
#    'Before that spot I clasped my hand,',
#    'In chilling care my heart was caught;',
#    'A bitter grief my soul unmanned',
#    'Though reason wiser comfort sought.',
#    'I mourned my pearl from freedom banned',
#    'With arguments that fiercely fought;',
#    "Though Christ's grace bade me understand",
#    'My wretched will fresh sorrow brought.',
#    'On flowery sward I fell, distraught;',
#    'Such fragrance to my senses shot',
#    'In deepest sleep I dreamt, methought,',
#    'On that dear pearl without a spot.'],
#   'text_as_string': "\nPearl, to delight a prince's day,\nFlawlessly set in gold so fair\nIn all the East, I dare to say,\nI have not found one to compare.\nSo round, so radiant in array,\nSo small, so smooth her contours were,\nWherever I judged jewels gay\nI set her worth as truly rare.\nI lost her in a garden where\nThrough grass she fell to earthen plot;\nWounded by love beyond repair\nI mourn that pearl without a spot.\nSince from that spot it fled that day\nI waited oft, in hope to see\nWhat once could drive my gloom away\nAnd charge my very soul with glee;\nBut heavy on my heart it lay\nAnd filled my breast with misery.\nYet no song ever seemed so gay\nAs that quiet hour let steal to me\nThough in my heart one thought ran free,\nHer fresh face wrapped in earthly clot;\nEarth, you have marred her purity,\nMy secret pearl without a spot.\n\nThat spot of spices needs must spread\nWhere such rich bounty doth decay,\nWith yellow flowers and blue and red\nThat shine so bright in sun's clear ray.\nFlower and fruit can ne'er be dead\nWhere that pearl slipped into the clay,\nFor grass will grow from seed once shed\nOr grain could not be stored away,\nAnd good will always good repay.\nThis comely seed shall perish not,\nAnd spices will their fruit display\nFrom that dear pearl without a spot.\nFrom that spot I in speech expound\nI entered in that garden green,\nAs August's season came around\nWhen corn is cut with sickles keen,\nThere that pearl rolled into the ground,\nShadowed with plants both bright and clean,\nWallflower, ginger, gromwell abound\nBright peonies scattered in between;\nThough they were seemly to be seen\nNo less in their scent my sense caught;\nAnd there that jewel long has been,\nMy precious pearl without a spot.\n\nBefore that spot I clasped my hand,\nIn chilling care my heart was caught;\nA bitter grief my soul unmanned\nThough reason wiser comfort sought.\nI mourned my pearl from freedom banned\nWith arguments that fiercely fought;\nThough Christ's grace bade me understand\nMy wretched will fresh sorrow brought.\nOn flowery sward I fell, distraught;\nSuch fragrance to my senses shot\nIn deepest sleep I dreamt, methought,\nOn that dear pearl without a spot.\n",
#   'title': 'Pearl, Part I'},
#  {'lines': ['That spot my spirit fled apace',
#    'And let my body dreaming lie.',
#    "My soul set forth in God's good grace",
#    'To range where marvels multiply.',
#    'In all this world I knew no place',
#    'Like this, where such cliffs clove the sky.',
#    'Towards the woods I turned my face,',
#    'Where splendid rocks I could descry.',
#    'None could believe aught could supply',
#    'Such gleaming glory to the sight;',
#    'No fabric that men weave could vie',
#    'With all that glorious splendour bright',
#    '',
#    'In splendour shone those downland sides',
#    'Clear did those cliffs their nature show,',
#    'And, bright about them, woodland rides',
#    'With tree-trunks blue as indigo;',
#    'Like silver, each leave open slides',
#    'And gently flickers to and fro;',
#    'When broken cloud above them glides',
#    'With shimmering sheen I see them glow.',
#    'The gravel on the ground below',
#    'Was precious pearls of Orient light;',
#    "The sunlight's beams could scarcely show",
#    'Against that glorious splendour bright.',
#    'The splendour of those bright hills there',
#    'My spirit freed from my side fate;',
#    'Refreshing was the fragrance clear',
#    'Of fruits, as though of food I ate;',
#    'Birds flew in all the woodland near',
#    'Of myriad hue, both small and great,',
#    'Cytole and cithern none could hear',
#    'To match a sound so delicate;',
#    'The notes their wing-beats did create',
#    'Made sounds of such sweet delight',
#    'Such charm no man could fabricate,',
#    'As here in all their splendour bright.',
#    '',
#    'The splendour bright of that display,',
#    'The wood where fortune smiled on me,',
#    'The glory thereof to portray',
#    'No man could render worthily.',
#    'I wandered joyful on my way;',
#    'No height could do me injury.',
#    'As through the woods my footsteps stray',
#    'Field, shrub, and spice, and each pear-tree,',
#    'Hedgerow and stream and banks I see',
#    'Like gold thread shines each wooded height;',
#    'I came to a streamlet running free;',
#    'Lord, glorious was that splendour bright !',
#    'The splendour of the water deep',
#    'Was lovely banks of beryl clear',
#    'And sweetly did that water sweep,',
#    'Flowing with murmuring sound anear.',
#    'Its depths each standing stone did steep,',
#    'And, as through glass, bright gleams appear',
#    'As streaming stars, when mortals sleep,',
#    "Sine in the heavens when winter's here;",
#    'Each pebble in that sparkling mere,',
#    'Emerald and sapphire, all unite;',
#    'Its glowing radiance without peer,',
#    'So dear to me that splendour bright.'],
#   'text_as_string': "\nThat spot my spirit fled apace\nAnd let my body dreaming lie.\nMy soul set forth in God's good grace\nTo range where marvels multiply.\nIn all this world I knew no place\nLike this, where such cliffs clove the sky.\nTowards the woods I turned my face,\nWhere splendid rocks I could descry.\nNone could believe aught could supply\nSuch gleaming glory to the sight;\nNo fabric that men weave could vie\nWith all that glorious splendour bright\n\nIn splendour shone those downland sides\nClear did those cliffs their nature show,\nAnd, bright about them, woodland rides\nWith tree-trunks blue as indigo;\nLike silver, each leave open slides\nAnd gently flickers to and fro;\nWhen broken cloud above them glides\nWith shimmering sheen I see them glow.\nThe gravel on the ground below\nWas precious pearls of Orient light;\nThe sunlight's beams could scarcely show\nAgainst that glorious splendour bright.\nThe splendour of those bright hills there\nMy spirit freed from my side fate;\nRefreshing was the fragrance clear\nOf fruits, as though of food I ate;\nBirds flew in all the woodland near\nOf myriad hue, both small and great,\nCytole and cithern none could hear\nTo match a sound so delicate;\nThe notes their wing-beats did create\nMade sounds of such sweet delight\nSuch charm no man could fabricate,\nAs here in all their splendour bright.\n\nThe splendour bright of that display,\nThe wood where fortune smiled on me,\nThe glory thereof to portray\nNo man could render worthily.\nI wandered joyful on my way;\nNo height could do me injury.\nAs through the woods my footsteps stray\nField, shrub, and spice, and each pear-tree,\nHedgerow and stream and banks I see\nLike gold thread shines each wooded height;\nI came to a streamlet running free;\nLord, glorious was that splendour bright !\nThe splendour of the water deep\nWas lovely banks of beryl clear\nAnd sweetly did that water sweep,\nFlowing with murmuring sound anear.\nIts depths each standing stone did steep,\nAnd, as through glass, bright gleams appear\nAs streaming stars, when mortals sleep,\nSine in the heavens when winter's here;\nEach pebble in that sparkling mere,\nEmerald and sapphire, all unite;\nIts glowing radiance without peer,\nSo dear to me that splendour bright.\n",
#   'title': 'Pearl, Part II'},
#  {'lines': ['The splendour of those downs and dales,',
#    'Of woods and water, lovely plains',
#    'Increased my joy, soothed my travails,',
#    'Removed all stress, destroyed all pains.',
#    'Beside a stream that never fails',
#    'In bliss I travel; naught restrains',
#    'My onward journey through those vales;',
#    'The greater joy my heart contains.',
#    'As fortune at her whim constrains,',
#    'And solace sends, or trials sore,',
#    'So he who profits from these gains',
#    'Desires her favours more and more.',
#    '',
#    'And still more joy came in a trice',
#    'Than I, though had I time, could say',
#    'For earthly heart would not suffice',
#    'One tenth my pleasure to convey;',
#    'Because it seemed that Paradise',
#    'Perchance beyond those mountains lay;',
#    'I thought the stream a mere device',
#    'To join the pools and gardens gay;',
#    'Beyond the stream, in some strange way,',
#    'Some city lay spread out before.',
#    'The stream was deep; fear bade me stay,',
#    'Yet longing filled me more and more',
#    '',
#    'More and more and yet more still',
#    'I longed to see that other side;',
#    'If this bank could such joy instill',
#    'Still lovelier sights that shore supplied.',
#    'I stood and stared against my will;',
#    'At once to find a ford I tried,',
#    'But felt something threatened ill',
#    'The more I walked that brook beside.',
#    "'Gainst further progress reason cried",
#    'Though such delights might lie in store;',
#    'A newer thing I then espied',
#    'That moved my senses more and more.',
#    'More marvels to my sense repair',
#    'I looked and saw yet more anon,',
#    'A crystal cliff resplendent there',
#    'With royal rays of splendour shone;',
#    'And at its foot a child so fair',
#    'More courtly maiden there was none.',
#    'A gleaming mantle she did wear;',
#    'I knew her well from times long gone,',
#    'Like gold that craftsmen work upon',
#    'So shone that maid upon that shore,',
#    'And long my eyes did linger on',
#    'That maid, and knew her more and more.',
#    '',
#    'The more I scanned that lovely face,',
#    'That lovely form so long unseen,',
#    'Such gladness did my soul embrace',
#    'As in my life had never been.',
#    'My need to call her grew apace;',
#    'I wondered what this thing might mean;',
#    'To see her in so strange a place',
#    'Might deal my heart a blow too keen.',
#    'She raised her head; her face was clean',
#    'As polished ivory, I swore;',
#    'Shaken by things so unforeseen,',
#    'I longed to see her more and more'],
#   'text_as_string': "\nThe splendour of those downs and dales,\nOf woods and water, lovely plains\nIncreased my joy, soothed my travails,\nRemoved all stress, destroyed all pains.\nBeside a stream that never fails\nIn bliss I travel; naught restrains\nMy onward journey through those vales;\nThe greater joy my heart contains.\nAs fortune at her whim constrains,\nAnd solace sends, or trials sore,\nSo he who profits from these gains\nDesires her favours more and more.\n\nAnd still more joy came in a trice\nThan I, though had I time, could say\nFor earthly heart would not suffice\nOne tenth my pleasure to convey;\nBecause it seemed that Paradise\nPerchance beyond those mountains lay;\nI thought the stream a mere device\nTo join the pools and gardens gay;\nBeyond the stream, in some strange way,\nSome city lay spread out before.\nThe stream was deep; fear bade me stay,\nYet longing filled me more and more\n\nMore and more and yet more still\nI longed to see that other side;\nIf this bank could such joy instill\nStill lovelier sights that shore supplied.\nI stood and stared against my will;\nAt once to find a ford I tried,\nBut felt something threatened ill\nThe more I walked that brook beside.\n'Gainst further progress reason cried\nThough such delights might lie in store;\nA newer thing I then espied\nThat moved my senses more and more.\nMore marvels to my sense repair\nI looked and saw yet more anon,\nA crystal cliff resplendent there\nWith royal rays of splendour shone;\nAnd at its foot a child so fair\nMore courtly maiden there was none.\nA gleaming mantle she did wear;\nI knew her well from times long gone,\nLike gold that craftsmen work upon\nSo shone that maid upon that shore,\nAnd long my eyes did linger on\nThat maid, and knew her more and more.\n\nThe more I scanned that lovely face,\nThat lovely form so long unseen,\nSuch gladness did my soul embrace\nAs in my life had never been.\nMy need to call her grew apace;\nI wondered what this thing might mean;\nTo see her in so strange a place\nMight deal my heart a blow too keen.\nShe raised her head; her face was clean\nAs polished ivory, I swore;\nShaken by things so unforeseen,\nI longed to see her more and more\n",
#   'title': 'Pearl, Part III'},
#  {'lines': ['Against my will arose more fear;',
#    'I stood stock still and dared not call.',
#    'With mouth set fast, but eye still not clear',
#    'I stood as still as a hawk in hall.',
#    'I thought her purpose spiritual cheer',
#    'And yet I feared what might befall,',
#    'That she might stop ere I drew near',
#    'And might escape me after all;',
#    'That gracious girl, so smooth, so small,',
#    'So free of stain, so seeming slight,',
#    'Royally clad, rose up withal,',
#    'A precious maid in pearls bedight.',
#    '',
#    'With pearls bedight most royally',
#    "There by God's grace might now be seen,",
#    'When she, as fresh as fleur-de-lys,',
#    'Came straightaway down to the bank between,',
#    'Her linen gleaming white I see,',
#    'Open at sides, bright with a sheen',
#    'Of lovelier pearls, it seemed to me',
#    'Than in my sight had ever been;',
#    'With hanging sleeves so wide and clean',
#    'And double rows of pearls so bright',
#    'Her kirtle matched that lovely scene,',
#    'With precious pearls richly bedight.',
#    'Bedight with pearls her crown arrayed;',
#    'With pearls and with no other stone,',
#    'High-pinnacled in pearls displayed',
#    'With figured flowers thereupon,',
#    'And on her head no covering laid.',
#    'Her face enclosèd round; as one',
#    'Like duke or earl her look was staid;',
#    'Her features white as whalebone shone;',
#    'Like burnished gold her tresses on',
#    'Her shoulders, all unbound, lay light;',
#    'Their hue defied comparison',
#    "With wimple's edge in pearls bedight.",
#    '',
#    'Bedight with pearls at every hem',
#    'Of wrists, hands, sides and throat I saw;',
#    'With whitest pearl, no other gem,',
#    'And gleaming white the dress she wore;',
#    'Richer than any diadem',
#    'A pearl upon her breast she bore;',
#    'No man might praise it or condemn,',
#    'Its worth would surely overawe.',
#    "I judge no tongue e'er found before ",
#    'Words to describe that glorious sight,',
#    'So clean it was, so clear, so pure.',
#    'That precious pearl there so bedight.',
#    'Bedight in pearls, that precious piece',
#    'From that far bank came to the shore.',
#    'No happier man from here to Greece',
#    'To see her stand the brink before.',
#    'She was more close than aunt or niece;',
#    'And therefore was my joy the more.',
#    'The fairest words she did release,',
#    "Bowed low as e'er she did of yore,",
#    'Removed her crown of richest store',
#    'And hailed me with a sweet delight,',
#    'Well for the man my mother bore',
#    'To greet that maid in pearls bedight !',
#    '',
#    "'O Pearl,' I said, 'in pearls bedight,",
#    'Are you my pearl for whom I cried,',
#    'For whom I grieved alone at night ?',
#    'Much longing I for you have sighed',
#    'Since into grass you left my sight.',
#    'Sorrow and grief with me reside',
#    'While you remain in true delight',
#    'In Paradise, in peace to abide.',
#    'What fate did now my pearl betide',
#    'And left me here in grief and care ?',
#    'Since you were severed from my side',
#    "I am a joyless jeweller.'",
#    'That jewel then in gems arrayed',
#    'Lifted to me those eyes of grey,',
#    'And donned her crown, of jewels made,',
#    'And gravely then I heard her say:',
#    "'Sir, your conclusion is mislaid",
#    'To say your pearl has fled away,',
#    'That is in such a casket laid',
#    'As in this gracious garden gay,',
#    'To dwell in joy in endless day;',
#    'Never can loss or grief come near.',
#    'No pearl in such a casket lay,',
#    "'Twould seem, for any jeweller.'",
#    '',
#    "'But, jeweller kind, if you must lose",
#    'Your joy in a gem to you so dear,',
#    'I think you do yourself confuse,',
#    'Your thought short-lived, your view unclear.',
#    'She was a rose which could not choose',
#    'But bloom and fade by laws austere.',
#    'The casket naturally endues',
#    'The pearl it holds with worth most clear.',
#    'And yet you call your fate severe',
#    'When much from naught was offered there;',
#    'The cure you curse lay always near,',
#    "You most unnatural jeweller.'",
#    'A jewel was this maid to me',
#    'And jewels were her noble speech.',
#    "'Indeed,' I said, 'most happily",
#    'In my distress you make a breach;',
#    'May my great fault forgiven be !',
#    'I thought my pearl far out of reach',
#    'Now I have found it, great my glee;',
#    "I'Il dwell in woods of oak and beech,",
#    'And love the laws my Lord doth teach',
#    'That have provided joys sincere.',
#    'And if yon bank I now could reaeh,',
#    "I'd be a joyful jeweller.'",
#    '',
#    "Jeweller,' said this gern sublime,",
#    "'You jest ! You lack all sanity !",
#    'Three words you utter at one time;',
#    'Ill-judged, in truth, were they all three.',
#    'Your thought no reason has nor rhyme;',
#    'Your words before your thoughts run free.',
#    "You say that you believe that I'm",
#    'Lodged in this vale, for that you see;',
#    'And then you say, in this country',
#    'That you can dwell with me right here;',
#    'Third, you may cross the stream to me-',
#    "That may no joyful jeweller.'"],
#   'text_as_string': "\nAgainst my will arose more fear;\nI stood stock still and dared not call.\nWith mouth set fast, but eye still not clear\nI stood as still as a hawk in hall.\nI thought her purpose spiritual cheer\nAnd yet I feared what might befall,\nThat she might stop ere I drew near\nAnd might escape me after all;\nThat gracious girl, so smooth, so small,\nSo free of stain, so seeming slight,\nRoyally clad, rose up withal,\nA precious maid in pearls bedight.\n\nWith pearls bedight most royally\nThere by God's grace might now be seen,\nWhen she, as fresh as fleur-de-lys,\nCame straightaway down to the bank between,\nHer linen gleaming white I see,\nOpen at sides, bright with a sheen\nOf lovelier pearls, it seemed to me\nThan in my sight had ever been;\nWith hanging sleeves so wide and clean\nAnd double rows of pearls so bright\nHer kirtle matched that lovely scene,\nWith precious pearls richly bedight.\nBedight with pearls her crown arrayed;\nWith pearls and with no other stone,\nHigh-pinnacled in pearls displayed\nWith figured flowers thereupon,\nAnd on her head no covering laid.\nHer face enclosèd round; as one\nLike duke or earl her look was staid;\nHer features white as whalebone shone;\nLike burnished gold her tresses on\nHer shoulders, all unbound, lay light;\nTheir hue defied comparison\nWith wimple's edge in pearls bedight.\n\nBedight with pearls at every hem\nOf wrists, hands, sides and throat I saw;\nWith whitest pearl, no other gem,\nAnd gleaming white the dress she wore;\nRicher than any diadem\nA pearl upon her breast she bore;\nNo man might praise it or condemn,\nIts worth would surely overawe.\nI judge no tongue e'er found before \nWords to describe that glorious sight,\nSo clean it was, so clear, so pure.\nThat precious pearl there so bedight.\nBedight in pearls, that precious piece\nFrom that far bank came to the shore.\nNo happier man from here to Greece\nTo see her stand the brink before.\nShe was more close than aunt or niece;\nAnd therefore was my joy the more.\nThe fairest words she did release,\nBowed low as e'er she did of yore,\nRemoved her crown of richest store\nAnd hailed me with a sweet delight,\nWell for the man my mother bore\nTo greet that maid in pearls bedight !\n\n'O Pearl,' I said, 'in pearls bedight,\nAre you my pearl for whom I cried,\nFor whom I grieved alone at night ?\nMuch longing I for you have sighed\nSince into grass you left my sight.\nSorrow and grief with me reside\nWhile you remain in true delight\nIn Paradise, in peace to abide.\nWhat fate did now my pearl betide\nAnd left me here in grief and care ?\nSince you were severed from my side\nI am a joyless jeweller.'\nThat jewel then in gems arrayed\nLifted to me those eyes of grey,\nAnd donned her crown, of jewels made,\nAnd gravely then I heard her say:\n'Sir, your conclusion is mislaid\nTo say your pearl has fled away,\nThat is in such a casket laid\nAs in this gracious garden gay,\nTo dwell in joy in endless day;\nNever can loss or grief come near.\nNo pearl in such a casket lay,\n'Twould seem, for any jeweller.'\n\n'But, jeweller kind, if you must lose\nYour joy in a gem to you so dear,\nI think you do yourself confuse,\nYour thought short-lived, your view unclear.\nShe was a rose which could not choose\nBut bloom and fade by laws austere.\nThe casket naturally endues\nThe pearl it holds with worth most clear.\nAnd yet you call your fate severe\nWhen much from naught was offered there;\nThe cure you curse lay always near,\nYou most unnatural jeweller.'\nA jewel was this maid to me\nAnd jewels were her noble speech.\n'Indeed,' I said, 'most happily\nIn my distress you make a breach;\nMay my great fault forgiven be !\nI thought my pearl far out of reach\nNow I have found it, great my glee;\nI'Il dwell in woods of oak and beech,\nAnd love the laws my Lord doth teach\nThat have provided joys sincere.\nAnd if yon bank I now could reaeh,\nI'd be a joyful jeweller.'\n\nJeweller,' said this gern sublime,\n'You jest ! You lack  ...
#   'title': 'Pearl, Part IV'},
#  {'lines': ["'I give that jeweller little praise",
#    'Who trusts the witness of his eye,',
#    'And much to blame, and lacking grace,',
#    'Who thinks our Lord would make a lie,',
#    'Who faithfully swore your soul to raise,',
#    'Though fate decreed your flesh should die.',
#    'You set his words in crooked ways',
#    'Accepting naught your eyes deny.',
#    'That is a proof of pride too high,',
#    'With which no good man could agree,',
#    'Accepting naught he cannot try',
#    "Unless his judgement so decree.'",
#    '',
#    "'Judge for yourself if, as a man,",
#    "Such words to God you e'er should say.",
#    'You think to dwell here, if you can,',
#    'First you must needs ask if you may.',
#    'And you will learn there is a ban;',
#    'To cross this stream without delay',
#    'Offends against the heavenly plan.',
#    'First, you must sink into the clay;',
#    'In Eden, man dared disobey',
#    'Because he lacked humility;',
#    'Now man through death must make his way',
#    "For God so judged. 'Tis his decree.",
#    "Am I then judged,' I said, 'my sweet,",
#    'To grieve again? Then I must pine;',
#    'To find, then lose, is loss complete.',
#    'Must I accept, my life consign',
#    'To loss and death? It is not meet',
#    'That you, my pearl, make me repine;',
#    'Gain that brings tears is mere deceit.',
#    'If I must now myself resign,',
#    'I care not how low I decline',
#    'Nor how far hence I now must flee;',
#    'My pearl is lost that once was mine,',
#    'Such judgement sorrow must decree.',
#    '',
#    "'You judge this nothing but distress,'",
#    "Then said that maid, 'Why do you so ?",
#    'He who concerns himself with less',
#    'Must thoughts of greater loss forgo.',
#    'Remember Him who lives to bless,',
#    'And still love God, come weal or woe.',
#    'Do not complain when, comfortless,',
#    'You wax impatient, for, although',
#    'You leap as high as any doe',
#    'And writhe and moan in agony,',
#    'When you can then no further go',
#    'Abide His judgement, His decree.',
#    'If you judge Him, and Him accuse,',
#    'He will not turn one step aside;',
#    'His recompense you then will lose;',
#    'Your sorrow then you must abide.',
#    'Cease all your wrangling and abuse',
#    'And in His mercy still confide.',
#    'Compassion he will not refuse,',
#    'His power thus is magnified.',
#    'For, though you grieve, and seek to hide',
#    'The depth of all your misery,',
#    'His grace is ever by your side,',
#    "And He will judge. 'Tis His decree.'"],
#   'text_as_string': "\n'I give that jeweller little praise\nWho trusts the witness of his eye,\nAnd much to blame, and lacking grace,\nWho thinks our Lord would make a lie,\nWho faithfully swore your soul to raise,\nThough fate decreed your flesh should die.\nYou set his words in crooked ways\nAccepting naught your eyes deny.\nThat is a proof of pride too high,\nWith which no good man could agree,\nAccepting naught he cannot try\nUnless his judgement so decree.'\n\n'Judge for yourself if, as a man,\nSuch words to God you e'er should say.\nYou think to dwell here, if you can,\nFirst you must needs ask if you may.\nAnd you will learn there is a ban;\nTo cross this stream without delay\nOffends against the heavenly plan.\nFirst, you must sink into the clay;\nIn Eden, man dared disobey\nBecause he lacked humility;\nNow man through death must make his way\nFor God so judged. 'Tis his decree.\nAm I then judged,' I said, 'my sweet,\nTo grieve again? Then I must pine;\nTo find, then lose, is loss complete.\nMust I accept, my life consign\nTo loss and death? It is not meet\nThat you, my pearl, make me repine;\nGain that brings tears is mere deceit.\nIf I must now myself resign,\nI care not how low I decline\nNor how far hence I now must flee;\nMy pearl is lost that once was mine,\nSuch judgement sorrow must decree.\n\n'You judge this nothing but distress,'\nThen said that maid, 'Why do you so ?\nHe who concerns himself with less\nMust thoughts of greater loss forgo.\nRemember Him who lives to bless,\nAnd still love God, come weal or woe.\nDo not complain when, comfortless,\nYou wax impatient, for, although\nYou leap as high as any doe\nAnd writhe and moan in agony,\nWhen you can then no further go\nAbide His judgement, His decree.\nIf you judge Him, and Him accuse,\nHe will not turn one step aside;\nHis recompense you then will lose;\nYour sorrow then you must abide.\nCease all your wrangling and abuse\nAnd in His mercy still confide.\nCompassion he will not refuse,\nHis power thus is magnified.\nFor, though you grieve, and seek to hide\nThe depth of all your misery,\nHis grace is ever by your side,\nAnd He will judge. 'Tis His decree.'\n",
#   'title': 'Pearl, Part VI'}]

# %% [markdown]
# In the cell below, loop through all_texts and print out the title of each text. (This is the only code you need to write for Part One.)

# %%
###Write your code here
for text in all_texts:
  print(text['title'])
# Out:
# Pearl, Part I
# Pearl, Part II
# Pearl, Part III
# Pearl, Part IV
# Pearl, Part VI

# %% [markdown]
# ## Part Two:  searching within lists and dictionaries
# In this part, we will be searching through each text and printing out a desired result. The searches, including loops and printing should all be defined in the function. The second cell should just have to function call that executes the function. I have written an example function and call for the first search. For each function that you write you should copy the original function and modify it so what does what I ask for.
#
# For the first five functions, there are no parameters passed to the functions--the calls will just execute the function. Go step-by-step and take your time.

# %%
def get_lengths():
    for text in all_texts:
        print(text['title'])
        print(len(text['text_as_string']))
        print("------------")

# %%
get_lengths()
# Out:
# Pearl, Part I
# 2132
# ------------
# Pearl, Part II
# 2189
# ------------
# Pearl, Part III
# 2119
# ------------
# Pearl, Part IV
# 4250
# ------------
# Pearl, Part VI
# 2083
# ------------

# %% [markdown]
# Question 1
# Now write a function that gets the **line count for each poem** (or sentence count for each piece of prose). This function is going to be very similar to the last one. Instead of accessing the whole text via text['text_as_string'] which is a string, you need to access the list of lines/sentences and get the length of that list. Everything else should be the same.

# %%
#Write your function here, name it get_line_count()
def get_line_count():
  for text in all_texts:
    print(text['title'])
    print(len(text['lines']))
    print("------------")

# %%
get_line_count()
# Out:
# Pearl, Part I
# 62
# ------------
# Pearl, Part II
# 62
# ------------
# Pearl, Part III
# 63
# ------------
# Pearl, Part IV
# 125
# ------------
# Pearl, Part VI
# 62
# ------------

# %% [markdown]
# Question 2
# Now write a function that prints out **one random line or sentence from each text**. Again, this function will look much the same as the last ones, but instead of getting numbers you need to get actual lines. I have included the necessary import and an example of how to get random integers. Basically, for each text you need to get one element from the list of lines/ sentences with a random number between 0 and the length of the list.

# %%
from random import randint
#Write your function here name it show_random_lines()
def show_random_lines():
  for text in all_texts:
    random_num = randint(0, len(text['lines']) - 1)
    print(text['title'])
    print(text['lines'][random_num])
    print('------------------------')

#This should be inside the inner loop 
#so you get a fresh random number for each text
#And it should not be from 0 to 9, but 0 to what?
#Keep in mind that the range (0,9) give you any number 
#from 0 to 9 including both 0 and 9.

# %%
show_random_lines()
# Out:
# Pearl, Part I
# But heavy on my heart it lay
# ------------------------
# Pearl, Part II
# To range where marvels multiply.
# ------------------------
# Pearl, Part III
# In bliss I travel; naught restrains
# ------------------------
# Pearl, Part IV
# Your thought no reason has nor rhyme;
# ------------------------
# Pearl, Part VI
# To find, then lose, is loss complete.
# ------------------------

# %% [markdown]
# Question 3
# This is a little bit different--instead of printing out something from each text, I want you to **print the entire text of the longest text**. Remember in the first function, I printed out the length of each text. Well, you need to test for the longest text as you look through and when you're done looping through print out the one that is longest.
#
# **Major hints!**: To do this you will need two **tracking variables** set before the loop runs: A numerical one that tracks the longest length (the number), and string variable remembers the actual text that has that length.
#
# Like this: longest_length = 0 and longest_text = ""
#
# When you loop through you need to test if each text was longer than the last one, and if it is longer--you update longest_length and longest_text to reflect the highest length, and the actual text. When the loop is over you then print out that longest_text string.

# %%
#Write your function here, name it longest_text()
def longest_text():
  longest_length = 0
  longest_text = ''

  for text in all_texts:
    if len(text['text_as_string']) > longest_length:
      longest_length = len(text['text_as_string'])
      longest_text = text['text_as_string']

  print(longest_text)

# %%
longest_text()
# Out:
# Against my will arose more fear;
# I stood stock still and dared not call.
# With mouth set fast, but eye still not clear
# I stood as still as a hawk in hall.
# I thought her purpose spiritual cheer
# And yet I feared what might befall,
# That she might stop ere I drew near
# And might escape me after all;
# That gracious girl, so smooth, so small,
# So free of stain, so seeming slight,
# Royally clad, rose up withal,
# A precious maid in pearls bedight.
#
# With pearls bedight most royally
# There by God's grace might now be seen,
# When she, as fresh as fleur-de-lys,
# Came straightaway down to the bank between,
# Her linen gleaming white I see,
# Open at sides, bright with a sheen
# Of lovelier pearls, it seemed to me
# Than in my sight had ever been;
# With hanging sleeves so wide and clean
# And double rows of pearls so bright
# Her kirtle matched that lovely scene,
# With precious pearls richly bedight.
# Bedight with pearls her crown arrayed;
# With pearls and with no other stone,
# High-pinnacled in pearls displayed
# With figured flowers thereupon,
# And on her head no covering laid.
# Her face enclosèd round; as one
# Like duke or earl her look was staid;
# Her features white as whalebone shone;
# Like burnished gold her tresses on
# Her shoulders, all unbound, lay light;
# Their hue defied comparison
# With wimple's edge in pearls bedight.
#
# Bedight with pearls at every hem
# Of wrists, hands, sides and throat I saw;
# With whitest pearl, no other gem,
# And gleaming white the dress she wore;
# Richer than any diadem
# A pearl upon her breast she bore;
# No man might praise it or condemn,
# Its worth would surely overawe.
# I judge no tongue e'er found before
# Words to describe that glorious sight,
# So clean it was, so clear, so pure.
# That precious pearl there so bedight.
# Bedight in pearls, that precious piece
# From that far bank came to the shore.
# No happier man from here to Greece
# To see her stand the brink before.
# She was more close than aunt or niece;
# And therefore was my joy the more.
# The fairest words she did release,
# Bowed low as e'er she did of yore,
# Removed her crown of richest store
# And hailed me with a sweet delight,
# Well for the man my mother bore
# To greet that maid in pearls bedight !
#
# 'O Pearl,' I said, 'in pearls bedight,
# Are you my pearl for whom I cried,
# For whom I grieved alone at night ?
# Much longing I for you have sighed
# Since into grass you left my sight.
# Sorrow and grief with me reside
# While you remain in true delight
# In Paradise, in peace to abide.
# What fate did now my pearl betide
# And left me here in grief and care ?
# Since you were severed from my side
# I am a joyless jeweller.'
# That jewel then in gems arrayed
# Lifted to me those eyes of grey,
# And donned her crown, of jewels made,
# And gravely then I heard her say:
# 'Sir, your conclusion is mislaid
# To say your pearl has fled away,
# That is in such a casket laid
# As in this gracious garden gay,
# To dwell in joy in endless day;
# Never can loss or grief come near.
# No pearl in such a casket lay,
# 'Twould seem, for any jeweller.'
#
# 'But, jeweller kind, if you must lose
# Your joy in a gem to you so dear,
# I think you do yourself confuse,
# Your thought short-lived, your view unclear.
# She was a rose which could not choose
# But bloom and fade by laws austere.
# The casket naturally endues
# The pearl it holds with worth most clear.
# And yet you call your fate severe
# When much from naught was offered there;
# The cure you curse lay always near,
# You most unnatural jeweller.'
# A jewel was this maid to me
# And jewels were her noble speech.
# 'Indeed,' I said, 'most happily
# In my distress you make a breach;
# May my great fault forgiven be !
# I thought my pearl far out of reach
# Now I have found it, great my glee;
# I'Il dwell in woods of oak and beech,
# And love the laws my Lord doth teach
# That have provided joys sincere.
# And if yon bank I now could reaeh,
# I'd be a joyful jeweller.'
#
# Jeweller,' said this gern sublime,
# 'You jest ! You lack all sanity !
# Three words you utter at one time;
# Ill-judged, in truth, were they all three.
# Your thought no reason has nor rhyme;
# Your words before your thoughts run free.
# You say that you believe that I'm
# Lodged in this vale, for that you see;
# And then you say, in this country
# That you can dwell with me right here;
# Third, you may cross the stream to me-
# That may no joyful jeweller.'

# %% [markdown]
# Question 4
# This is kind of a combination of the first two functions--write a function that gets the **average line/sentence length for each text**.

# %%
#Write your function here
import statistics
def average_line_length():
  for text in all_texts:
    avg_length = statistics.mean([len(line) for line in text['lines']])
    print(text['title'])
    print('Average line lenght:', avg_length)
    print('👺👺👺👺👺👺👺👺👺👺👺')

# %%
average_line_length()
# Out:
# Pearl, Part I
# Average line lenght: 33.37096774193548
# 👺👺👺👺👺👺👺👺👺👺👺
# Pearl, Part II
# Average line lenght: 34.29032258064516
# 👺👺👺👺👺👺👺👺👺👺👺
# Pearl, Part III
# Average line lenght: 32.61904761904762
# 👺👺👺👺👺👺👺👺👺👺👺
# Pearl, Part IV
# Average line lenght: 32.992
# 👺👺👺👺👺👺👺👺👺👺👺
# Pearl, Part VI
# Average line lenght: 32.58064516129032
# 👺👺👺👺👺👺👺👺👺👺👺

# %% [markdown]
# Question 5
# **Print the longest line/sentence in each text**.
# This is similar to question 3--but your two tracking variables (longest_length and longest_line) need to be placed right before the inside loop--and then you print the lines each time the inside loop ends.

# %%
#Write your function here
def longest_line_in_each():
  print('┌────────────────────────────────┐')
  for text in all_texts:
    longest_length = 0
    longest_line = ''
    
    for line in text['lines']:
      if len(line) > longest_length:
        longest_length = len(line)
        longest_line = line
      
    
    print('│', text['title'])
    print('│', longest_line)
    print('├────────────────────────────────┤')

# %%
longest_line_in_each()
# Out:
# ┌────────────────────────────────┐
# │ Pearl, Part I
# │ Shadowed with plants both bright and clean,
# ├────────────────────────────────┤
# │ Pearl, Part II
# │ Field, shrub, and spice, and each pear-tree,
# ├────────────────────────────────┤
# │ Pearl, Part III
# │ Still lovelier sights that shore supplied.
# ├────────────────────────────────┤
# │ Pearl, Part IV
# │ With mouth set fast, but eye still not clear
# ├────────────────────────────────┤
# │ Pearl, Part VI
# │ Though fate decreed your flesh should die.
# ├────────────────────────────────┤

# %% [markdown]
# Question 6
# **Print the shortest single line/sentence out of all of the texts that is greater than zero**
# This is the tricky-ish: You need to place the tracking variables outside the loop (like question 4, but the loop through all of the lines, test for the shortest one (greater than 0).

# %%
#Write your function here
def shortest_of_all_lines():
  shortest_length = float('inf')
  shortest_line = ''
  
  for text in all_texts:
    for line in text['lines']:
      if len(line) > 0 and len(line) < shortest_length:
        shortest_length = len(line)
        shortest_line = line

  print('╔══════════════════════════╗')
  print('║', '{:<68}'.format(shortest_line) ,'║')
  print('╚══════════════════════════╝')

# %%
shortest_of_all_lines()
# Out:
# ╔══════════════════════════╗
# ║ Richer than any diadem                                               ║
# ╚══════════════════════════╝

# %% [markdown]
# ## searching with regular expressions
# In the functions below you will search all the texts using regular expressions. The first few of these functions should not be too challenging--you just need to adjust the regular expression inside the function. At points it gets a little more complex as you have to control the looping through the lists and dictionaries.

# %%
def get_this_word(word):
    my_regex = r"\b" + word + r"\b"
    for text in all_texts:
        result = [line for line in text['lines'] if re.search(my_regex, line, re.IGNORECASE)]
        if len(result) > 0:
            print(text['title'])
            [print(line) for line in result]
            print("------------")

# %%
get_this_word('deal')
# Out:
# Pearl, Part III
# Might deal my heart a blow too keen.
# ------------

# %% [markdown]
# Question 7
# Print out the lines that start with the word entered.  You just need to adjust the regular expression here.

# %%
#Write your function here
def line_starts_with(word):
  my_regex = r"^[']*\b" + word + r"\b"
  for text in all_texts:
    result = [line for line in text['lines'] if
              re.search(my_regex, line, re.IGNORECASE)]
    if len(result) > 0:
      print(text['title'])
      [print(line) for line in result]
      print("------------")

# %%
line_starts_with('the')
# Out:
# Pearl, Part II
# The gravel on the ground below
# The sunlight's beams could scarcely show
# The splendour of those bright hills there
# The notes their wing-beats did create
# The splendour bright of that display,
# The wood where fortune smiled on me,
# The glory thereof to portray
# The splendour of the water deep
# ------------
# Pearl, Part III
# The splendour of those downs and dales,
# The greater joy my heart contains.
# The stream was deep; fear bade me stay,
# The more I walked that brook beside.
# The more I scanned that lovely face,
# ------------
# Pearl, Part IV
# The fairest words she did release,
# The casket naturally endues
# The pearl it holds with worth most clear.
# The cure you curse lay always near,
# ------------
# Pearl, Part VI
# The depth of all your misery,
# ------------

# %% [markdown]
# Question 8
# Print out the lines that end with the word entered.  You just need to adjust the regular expression here.

# %%
#Write your function here
def line_ends_with(word):
  my_regex = r"\b" + word + r"\b[,.;!?']*$"
  for text in all_texts:
    result = [line for line in text['lines'] if
              re.search(my_regex, line, re.IGNORECASE)]
    if len(result) > 0:
      print(text['title'])
      [print(line) for line in result]
      print("------------")

# %%
line_ends_with('jeweller')
# Out:
# Pearl, Part IV
# I am a joyless jeweller.'
# 'Twould seem, for any jeweller.'
# You most unnatural jeweller.'
# I'd be a joyful jeweller.'
# That may no joyful jeweller.'
# ------------

# %% [markdown]
# Question 9
# Print out **how many times the word was found in each text.** In this case, instead of the list comprehension, you want to run a re.findall() on the string of the text (not the list) and then count the number of elements in the list of results.
#
# Hint: use the original function at the beginning of this section, and make the proper adjustments to the variable "result"

# %%
#Write your function here
def how_many_times(word):
  my_regex = r"\b" + word + r"\b"
  for text in all_texts:
    result = len(re.findall(my_regex, text['text_as_string'], re.IGNORECASE))
    if result > 0:
      print(text['title'])
      print(result)
      print("------------")

# %%
how_many_times('the')
# Out:
# Pearl, Part I
# 3
# ------------
# Pearl, Part II
# 17
# ------------
# Pearl, Part III
# 8
# ------------
# Pearl, Part IV
# 12
# ------------
# Pearl, Part VI
# 4
# ------------

# %% [markdown]
# Question 10
# Print out **the text that has the highest occurrence of the word** you searched for. This is similar to the last function, but here you need tracking variables like you had in Question 3.

# %%
#Write your function here
def text_with_most_occurance_of(word):
  my_regex = r"\b" + word + r"\b"
  number_of_results = 0
  text = ''
  for text in all_texts:
    result = len(re.findall(my_regex, text['text_as_string'], re.IGNORECASE))
    if result > number_of_results:
      number_of_results = result
      text = text['text_as_string']
      
  print('Number of results:', number_of_results)
  print(text)

# %%
text_with_most_occurance_of('pearl')
# Out:
# Number of results: 10
# {'title': 'Pearl, Part VI', 'text_as_string': "\n'I give that jeweller little praise\nWho trusts the witness of his eye,\nAnd much to blame, and lacking grace,\nWho thinks our Lord would make a lie,\nWho faithfully swore your soul to raise,\nThough fate decreed your flesh should die.\nYou set his words in crooked ways\nAccepting naught your eyes deny.\nThat is a proof of pride too high,\nWith which no good man could agree,\nAccepting naught he cannot try\nUnless his judgement so decree.'\n\n'Judge for yourself if, as a man,\nSuch words to God you e'er should say.\nYou think to dwell here, if you can,\nFirst you must needs ask if you may.\nAnd you will learn there is a ban;\nTo cross this stream without delay\nOffends against the heavenly plan.\nFirst, you must sink into the clay;\nIn Eden, man dared disobey\nBecause he lacked humility;\nNow man through death must make his way\nFor God so judged. 'Tis his decree.\nAm I then judged,' I said, 'my sweet,\nTo grieve again? Then I must pine;\nTo find, then lose, is loss complete.\nMust I accept, my life consign\nTo loss and death? It is not meet\nThat you, my pearl, make me repine;\nGain that brings tears is mere deceit.\nIf I must now myself resign,\nI care not how low I decline\nNor how far hence I now must flee;\nMy pearl is lost that once was mine,\nSuch judgement sorrow must decree.\n\n'You judge this nothing but distress,'\nThen said that maid, 'Why do you so ?\nHe who concerns himself with less\nMust thoughts of greater loss forgo.\nRemember Him who lives to bless,\nAnd still love God, come weal or woe.\nDo not complain when, comfortless,\nYou wax impatient, for, although\nYou leap as high as any doe\nAnd writhe and moan in agony,\nWhen you can then no further go\nAbide His judgement, His decree.\nIf you judge Him, and Him accuse,\nHe will not turn one step aside;\nHis recompense you then will lose;\nYour sorrow then you must abide.\nCease all your wrangling and abuse\nAnd in His mercy still confide.\nCompassion he will not refuse,\nHis power thus is magnified.\nFor, though you grieve, and seek to hide\nThe depth of all your misery,\nHis grace is ever by your side,\nAnd He will judge. 'Tis His decree.'\n", 'lines': ["'I give that jeweller little praise", 'Who trusts the witness of his eye,', 'And much to blame, and lacking grace,', 'Who thinks our Lord would make a lie,', 'Who faithfully swore your soul to raise,', 'Though fate decreed your flesh should die.', 'You set his words in crooked ways', 'Accepting naught your eyes deny.', 'That is a proof of pride too high,', 'With which no good man could agree,', 'Accepting naught he cannot try', "Unless his judgement so decree.'", '', "'Judge for yourself if, as a man,", "Such words to God you e'er should say.", 'You think to dwell here, if you can,', 'First you must needs ask if you may.', 'And you will learn there is a ban;', 'To cross this stream without delay', 'Offends against the heavenly plan.', 'First, you must sink into the clay;', 'In Eden, man dared disobey', 'Because he lacked humility;', 'Now man through death must make his way', "For God so judged. 'Tis his decree.", "Am I then judged,' I said, 'my sweet,", 'To grieve again? Then I must pine;', 'To find, then lose, is loss complete.', 'Must I accept, my life consign', 'To loss and death? It is not meet', 'That you, my pearl, make me repine;', 'Gain that brings tears is mere deceit.', 'If I must now myself resign,', 'I care not how low I decline', 'Nor how far hence I now must flee;', 'My pearl is lost that once was mine,', 'Such judgement sorrow must decree.', '', "'You judge this nothing but distress,'", "Then said that maid, 'Why do you so ?", 'He who concerns himself with less', 'Must thoughts of greater loss forgo.', 'Remember Him who lives to bless,', 'And still love God, come weal or woe.', 'Do not complain when, comfortless,', 'You wax impatient, for, although', 'You leap as high as any doe', 'And writhe and moan in agony,', 'When you can then no further go',  ...

# %% [markdown]
# Question 11
# Print out **lines containing words of the length asked**. We are sort of back to basics here, you just need to modify the regular expression of the first function (get_this_word(word)) so that it can take a number parameter for the length of characters in a word.

# %%
#Write your function here
def lines_with_words_this_length(length):
  my_regex = r"\w{" + length + r"}"
  for text in all_texts:
    result = [line for line in text['lines'] if
              re.search(my_regex, line, re.IGNORECASE)]
    if len(result) > 0:
      print(text['title'])
      [print(line) for line in result]
      print("------------")

# %%
lines_with_words_this_length('10')
# Out:
# Pearl, Part I
# Flawlessly set in gold so fair
# Wallflower, ginger, gromwell abound
# Though Christ's grace bade me understand
# On flowery sward I fell, distraught;
# ------------
# Pearl, Part II
# With shimmering sheen I see them glow.
# Refreshing was the fragrance clear
# ------------
# Pearl, Part III
# As fortune at her whim constrains,
# But felt something threatened ill
# A crystal cliff resplendent there
# Shaken by things so unforeseen,
# ------------
# Pearl, Part IV
# Came straightaway down to the bank between,
# Their hue defied comparison
# 'Sir, your conclusion is mislaid
# ------------
# Pearl, Part VI
# Who faithfully swore your soul to raise,
# Do not complain when, comfortless,
# His recompense you then will lose;
# Compassion he will not refuse,
# ------------

# %% [markdown]
# **Final question:** in this cell, describe two functions that you would like to write, not ones that you're able to write, but ones you think would be useful or interesting or fun. If you feel like trying to write it, go-ahead!

# %% [markdown]
# **Bonus question:** Write a function that counts word frequency: that is, it returns a dictionary with each unique word and its count, sorted by the most frequent. Note, this is highly stack-overflowable -- Python has some built in ways of doing this. If you're doing this, you might as well try to do it on your own. But it's up to you!

# %%
import pandas as pd

def word_frequencies(text):
  # tokenise all the words and add them to a list
  allwords = pd.Series(re.findall(r'\w+', text))

  # get a list of unique words from the tokens, by first lowercasing all of 
  # them 
  uniquewords = pd.Series(allwords.apply(lambda word: word.lower()).unique(),
                          name='word')

  # make a new dataframe, with a so far empty column
  df = pd.DataFrame(index=uniquewords, columns=['occurence'])

  # go through the list of words and count the occurences
  df['occurence'] = df.apply(lambda row: len(
    re.findall(r"\b" + row.name + r"\b",
               text,
               re.IGNORECASE)
  )
                             , axis=1)
  
  return df.sort_values('occurence', ascending=False)
 # yes, the I could now write an additional few lines to turn it back into a 
# dictionary, but I think a data frame will do just as nicely.
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>occurence</th>
#     </tr>
#     <tr>
#       <th>word</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>the</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>and</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>that</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>bright</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>could</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>of</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>splendour</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>i</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>my</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>in</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>to</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>as</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>no</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>all</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>each</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>such</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>did</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>was</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>with</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>where</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>me</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>like</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>when</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>on</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>those</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>their</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>them</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>glorious</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>clear</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>s</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>food</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ate</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>birds</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>flew</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>near</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>myriad</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>hue</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>beams</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>sunlight</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>light</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>above</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>leave</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>open</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>slides</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>gently</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>flickers</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>fro</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>broken</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>cloud</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>glides</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>orient</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>shimmering</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>sheen</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>glow</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>gravel</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ground</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>below</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>precious</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>pearls</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>dear</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>218 rows × 1 columns</p>
# </div>

# %%
word_frequencies(all_texts[0]['text_as_string'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>occurence</th>
#     </tr>
#     <tr>
#       <th>word</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>that</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>my</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>in</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>i</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>pearl</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>spot</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>and</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>a</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>to</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>so</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>with</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>without</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>from</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>her</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>though</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>will</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>s</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>bright</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>where</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>be</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>not</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>as</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>heart</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>on</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>the</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>fruit</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>seed</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>it</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>caught</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>once</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>clear</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ray</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>flower</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>can</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ne</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>er</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>purity</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>marred</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>you</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>earth</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>lay</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>filled</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>breast</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>misery</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>yet</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>song</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ever</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>seemed</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>quiet</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>hour</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>let</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>steal</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>thought</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ran</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>free</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>face</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>wrapped</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>earthly</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>clot</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>methought</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>234 rows × 1 columns</p>
# </div>

# %%
word_frequencies(all_texts[1]['text_as_string'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>occurence</th>
#     </tr>
#     <tr>
#       <th>word</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>the</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>and</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>that</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>bright</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>could</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>of</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>splendour</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>i</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>my</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>in</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>to</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>as</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>no</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>all</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>each</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>such</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>did</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>was</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>with</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>where</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>me</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>like</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>when</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>on</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>those</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>their</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>them</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>glorious</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>clear</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>s</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>food</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ate</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>birds</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>flew</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>near</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>myriad</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>hue</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>beams</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>sunlight</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>light</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>above</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>leave</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>open</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>slides</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>gently</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>flickers</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>fro</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>broken</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>cloud</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>glides</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>orient</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>shimmering</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>sheen</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>glow</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>gravel</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ground</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>below</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>precious</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>pearls</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>dear</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>218 rows × 1 columns</p>
# </div>

# %%
word_frequencies(all_texts[2]['text_as_string'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>occurence</th>
#     </tr>
#     <tr>
#       <th>word</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>more</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>and</th>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>i</th>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>my</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>that</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>a</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>her</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>the</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>to</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>in</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>so</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>stream</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>joy</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>might</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>yet</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>still</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>at</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>as</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>heart</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>did</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>was</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>long</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>such</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>see</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>lovely</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>of</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>those</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>lay</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>maid</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>upon</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>stared</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>against</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>will</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>once</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>find</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ford</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>bade</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>deep</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>pleasure</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>water</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>convey</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>because</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>it</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>seemed</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>paradise</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>perchance</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>mountains</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>thought</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>mere</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>device</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>join</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>pools</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>gardens</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>gay</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>way</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>city</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>spread</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>out</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>before</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>unforeseen</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>225 rows × 1 columns</p>
# </div>

# %%
word_frequencies(all_texts[3]['text_as_string'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>occurence</th>
#     </tr>
#     <tr>
#       <th>word</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>in</th>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>and</th>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>i</th>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>you</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>that</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>with</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>her</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>to</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>pearls</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>a</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>my</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>the</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>so</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>of</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>pearl</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>bedight</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>no</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>me</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>your</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>as</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>she</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>jeweller</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>was</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>for</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>this</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>might</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>it</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>most</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>now</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>from</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>light</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>unbound</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>shoulders</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>gold</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>wimple</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>burnished</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>shone</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>whalebone</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>features</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>staid</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>look</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>comparison</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>edge</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>its</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>wore</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>condemn</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>praise</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>breast</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>upon</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>diadem</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>richer</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>dress</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>every</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>whitest</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>saw</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>throat</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>hands</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>wrists</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>hem</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>stream</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>376 rows × 1 columns</p>
# </div>

# %%
word_frequencies(all_texts[4]['text_as_string'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>occurence</th>
#     </tr>
#     <tr>
#       <th>word</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>you</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>his</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>and</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>to</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>must</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>i</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>is</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>your</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>then</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>that</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>he</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>who</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>decree</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>if</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>not</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>will</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>my</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>for</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>judge</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>a</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>man</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>of</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>the</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>in</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>him</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>god</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>as</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>so</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>judgement</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>loss</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>pine</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>find</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>fate</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>complete</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>accept</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>life</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>consign</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>it</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>little</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>humility</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>lacked</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>because</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>offends</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>learn</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>there</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ban</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>cross</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>stream</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>without</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>delay</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>against</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>disobey</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>heavenly</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>plan</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>sink</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>into</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>clay</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>eden</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>dared</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>side</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>215 rows × 1 columns</p>
# </div>
